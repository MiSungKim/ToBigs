# %%
#import some necessary librairies

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
import matplotlib.pyplot as plt  # Matlab-style plotting
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn #ignore annoying warning (from sklearn and seaborn)


from scipy import stats
from scipy.stats import norm, skew

# %%
test = pd.read_csv('test_new.csv') 
train = pd.read_csv('train_new.csv')

# %%
train
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0      1          60       RL         65.0     8450   Pave   NaN      Reg
# 1      2          20       RL         80.0     9600   Pave   NaN      Reg
# 2      3          60       RL         68.0    11250   Pave   NaN      IR1
# 3      4          70       RL         60.0     9550   Pave   NaN      IR1
# 4      5          60       RL         84.0    14260   Pave   NaN      IR1
# 5      6          50       RL         85.0    14115   Pave   NaN      IR1
# 6      7          20       RL         75.0    10084   Pave   NaN      Reg
# 7      8          60       RL          NaN    10382   Pave   NaN      IR1
# 8      9          50       RM         51.0     6120   Pave   NaN      Reg
# 9     10         190       RL         50.0     7420   Pave   NaN      Reg
# 10    11          20       RL         70.0    11200   Pave   NaN      Reg
# 11    12          60       RL         85.0    11924   Pave   NaN      IR1
# 12    13          20       RL          NaN    12968   Pave   NaN      IR2
# 13    14          20       RL         91.0    10652   Pave   NaN      IR1
# 14    15          20       RL          NaN    10920   Pave   NaN      IR1
# 15    16          45       RM         51.0     6120   Pave   NaN      Reg
# 16    17          20       RL          NaN    11241   Pave   NaN      IR1
# 17    18          90       RL         72.0    10791   Pave   NaN      Reg
# 18    19          20       RL         66.0    13695   Pave   NaN      Reg
# 19    20          20       RL         70.0     7560   Pave   NaN      Reg
# 20    21          60       RL        101.0    14215   Pave   NaN      IR1
# 21    22          45       RM         57.0     7449   Pave  Grvl      Reg
# 22    23          20       RL         75.0     9742   Pave   NaN      Reg
# 23    24         120       RM         44.0     4224   Pave   NaN      Reg
# 24    25          20       RL          NaN     8246   Pave   NaN      IR1
# 25    26          20       RL        110.0    14230   Pave   NaN      Reg
# 26    27          20       RL         60.0     7200   Pave   NaN      Reg
# 27    28          20       RL         98.0    11478   Pave   NaN      Reg
# 28    29          20       RL         47.0    16321   Pave   NaN      IR1
# 29    30          30       RM         60.0     6324   Pave   NaN      IR1
# ..   ...         ...      ...          ...      ...    ...   ...      ...
# 830  831          20       RL         80.0    11900   Pave   NaN      IR1
# 831  832         160       FV         30.0     3180   Pave  Pave      Reg
# 832  833          60       RL         44.0     9548   Pave   NaN      IR1
# 833  834          20       RL        100.0    10004   Pave   NaN      Reg
# 834  835          20       RL         75.0     7875   Pave   NaN      Reg
# 835  836          20       RL         60.0     9600   Pave   NaN      Reg
# 836  837          30       RM         90.0     8100   Pave  Pave      Reg
# 837  838         160       RM         21.0     1680   Pave   NaN      Reg
# 838  839          20       RL         75.0     9525   Pave   NaN      Reg
# 839  840          50       RL         70.0    11767   Pave   NaN      Reg
# 840  841          70       RH          NaN    12155   Pave   NaN      IR1
# 841  842          70       RM         60.0    10440   Pave  Grvl      Reg
# 842  843          80       RL         82.0     9020   Pave   NaN      Reg
# 843  844          90       RL         80.0     8000   Pave   NaN      Reg
# 844  845          50       RM        100.0    12665   Pave  Grvl      IR1
# 845  846          85       RL          NaN    16647   Pave   NaN      IR1
# 846  847          60       RL         75.0     9317   Pave   NaN      Reg
# 847  848          20       RL         36.0    15523   Pave   NaN      IR1
# 848  849          50       RL         75.0    45600   Pave   NaN      IR2
# 849  850          80       RL         80.0     9600   Pave   NaN      Reg
# 850  851         120       RM         36.0     4435   Pave   NaN      Reg
# 851  852         120       RL          NaN     3196   Pave   NaN      Reg
# 852  853          75       RL         53.0     7128   Pave   NaN      Reg
# 853  854          80       RL          NaN    12095   Pave   NaN      IR1
# 854  855          20       RL        102.0    17920   Pave   NaN      Reg
# 855  856          20       RL          NaN     6897   Pave   NaN      IR1
# 856  857          80       RL          NaN    10970   Pave   NaN      IR1
# 857  858          60       RL         65.0     8125   Pave   NaN      Reg
# 858  859          20       RL         80.0    10400   Pave   NaN      Reg
# 859  860          60       RL          NaN    11029   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5           Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7           Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 10          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 11          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 12          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 13          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 14          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 15          Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 16          Lvl    AllPub  ...        0    NaN    NaN        Shed     700
# 17          Lvl    AllPub  ...        0    NaN    NaN        Shed     500
# 18          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 19          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 20          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 21          Bnk    AllPub  ...        0    NaN  GdPrv         NaN       0
# 22          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 23          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 24          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 25          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 26          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 27          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 28          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 29          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ..          ...       ...  ...      ...    ...    ...         ...     ...
# 830         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 831         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 832         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 833         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 834         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 835         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 836         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 837         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 838         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 839         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 840         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 841         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 842         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 843         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 844         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 845         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 846         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 847         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 848         Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 849         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 850         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 851         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 852         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 853         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 854         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 855         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 856         Low    AllPub  ...        0    NaN  MnPrv         NaN       0
# 857         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 858         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 859         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0        2   2008        WD         Normal  12.247699
# 1        5   2007        WD         Normal  12.109016
# 2        9   2008        WD         Normal  12.317171
# 3        2   2006        WD        Abnorml  11.849405
# 4       12   2008        WD         Normal  12.429220
# 5       10   2009        WD         Normal  11.870607
# 6        8   2007        WD         Normal  12.634606
# 7       11   2009        WD         Normal  12.206078
# 8        4   2008        WD        Abnorml  11.774528
# 9        1   2008        WD         Normal  11.678448
# 10       2   2008        WD         Normal  11.771444
# 11       7   2006       New        Partial  12.751303
# 12       9   2008        WD         Normal  11.877576
# 13       8   2007       New        Partial  12.540761
# 14       5   2008        WD         Normal  11.964007
# 15       7   2007        WD         Normal  11.790565
# 16       3   2010        WD         Normal  11.911708
# 17      10   2006        WD         Normal  11.407576
# 18       6   2008        WD         Normal  11.976666
# 19       5   2009       COD        Abnorml  11.842236
# 20      11   2006       New        Partial  12.692506
# 21       6   2007        WD         Normal  11.845110
# 22       9   2008        WD         Normal  12.345839
# 23       6   2007        WD         Normal  11.774528
# 24       5   2010        WD         Normal  11.944714
# 25       7   2009        WD         Normal  12.454108
# 26       5   2010        WD         Normal  11.811555
# 27       5   2010        WD         Normal  12.631344
# 28      12   2006        WD         Normal  12.242891
# 29       5   2008        WD         Normal  11.134604
# ..     ...    ...       ...            ...        ...
# 830      6   2008        WD         Normal  12.019749
# 831      6   2006        WD         Normal  11.925042
# 832      1   2010        WD         Normal  12.375820
# 833      2   2009        WD         Normal  12.025755
# 834      9   2008        WD         Normal  11.849048
# 835      2   2010        WD         Normal  11.759793
# 836      6   2007       COD         Normal  11.941462
# 837     11   2008        WD         Normal  11.512935
# 838      6   2008        WD         Normal  11.877576
# 839      5   2008        WD         Normal  11.779136
# 840      3   2008        WD         Normal  11.849405
# 841      6   2008        WD         Normal  11.967187
# 842      5   2008        WD         Normal  12.071975
# 843      7   2007        WD         Normal  11.856522
# 844      6   2008        WD         Normal  11.944065
# 845      1   2007        WD         Normal  12.049425
# 846      7   2009        WD         Normal  12.269052
# 847      8   2009        WD         Normal  11.801864
# 848      9   2008        WD         Normal  12.388398
# 849      8   2007        WD         Normal  12.138869
# 850     11   2007        WD         Normal  11.786770
# 851      5   2006        WD         Normal  12.278398
# 852      8   2007        WD         Normal  12.007628
# 853      8   2009        WD         Normal  11.970357
# 854      7   2006        WD        Abnorml  12.043560
# 855      4   2010        WD         Normal  11.751950
# 856     10   2008        WD         Normal  11.898195
# 857      3   2009        WD         Normal  12.066816
# 858      6   2009        WD         Family  11.931642
# 859      8   2006        WD         Normal  12.429220
#
# [860 rows x 81 columns]

# %%
test
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     861          50       RL         55.0     7642   Pave   NaN      Reg
# 1     862         190       RL         75.0    11625   Pave   NaN      Reg
# 2     863          20       RL         81.0     9672   Pave   NaN      Reg
# 3     864          20       RL         70.0     7931   Pave   NaN      Reg
# 4     865          20       FV         72.0     8640   Pave   NaN      Reg
# 5     866          20       RL          NaN     8750   Pave   NaN      IR1
# 6     867          20       RL         67.0    10656   Pave   NaN      IR1
# 7     868          20       RL         85.0     6970   Pave   NaN      Reg
# 8     869          60       RL          NaN    14762   Pave   NaN      IR2
# 9     870          60       RL         80.0     9938   Pave   NaN      Reg
# 10    871          20       RL         60.0     6600   Pave   NaN      Reg
# 11    872          60       RL         70.0     8750   Pave   NaN      Reg
# 12    873          20       RL         74.0     8892   Pave   NaN      Reg
# 13    874          40       RL         60.0    12144   Pave   NaN      Reg
# 14    875          50       RM         52.0     5720   Pave   NaN      Reg
# 15    876          60       FV         75.0     9000   Pave   NaN      Reg
# 16    877          20       RL         94.0    25286   Pave   NaN      Reg
# 17    878          60       RL         74.0     8834   Pave   NaN      Reg
# 18    879          85       RL         88.0    11782   Pave   NaN      IR1
# 19    880          20       RL          NaN     7000   Pave   NaN      IR1
# 20    881          20       RL         60.0     7024   Pave   NaN      Reg
# 21    882          50       RL         44.0    13758   Pave   NaN      IR1
# 22    883          60       RL          NaN     9636   Pave   NaN      IR1
# 23    884          75       RL         60.0     6204   Pave   NaN      Reg
# 24    885          20       RL         65.0     7150   Pave   NaN      Reg
# 25    886         120       FV         50.0     5119   Pave   NaN      IR1
# 26    887          90       RL         70.0     8393   Pave   NaN      Reg
# 27    888          50       RL         59.0    16466   Pave   NaN      IR1
# 28    889          20       RL         95.0    15865   Pave   NaN      IR1
# 29    890          20       RL        128.0    12160   Pave   NaN      Reg
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 570  1431          60       RL         60.0    21930   Pave   NaN      IR3
# 571  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 572  1433          30       RL         60.0    10800   Pave  Grvl      Reg
# 573  1434          60       RL         93.0    10261   Pave   NaN      IR1
# 574  1435          20       RL         80.0    17400   Pave   NaN      Reg
# 575  1436          20       RL         80.0     8400   Pave   NaN      Reg
# 576  1437          20       RL         60.0     9000   Pave   NaN      Reg
# 577  1438          20       RL         96.0    12444   Pave   NaN      Reg
# 578  1439          20       RM         90.0     7407   Pave   NaN      Reg
# 579  1440          60       RL         80.0    11584   Pave   NaN      Reg
# 580  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 581  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 582  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 583  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 584  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 585  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 586  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 587  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 588  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 589  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 590  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 591  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 592  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 593  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 594  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 595  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 596  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 597  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 598  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 599  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#     LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# 1           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 2           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# 3           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# 4           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 5           Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 6           HLS    AllPub  ...           0        0    NaN    NaN         NaN
# 7           Lvl    AllPub  ...           0        0    NaN    NaN        Shed
# 8           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 9           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# 10          Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 11          Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 12          Lvl    AllPub  ...           0        0    NaN   GdWo         NaN
# 13          Lvl    AllPub  ...           0        0    NaN    NaN        Othr
# 14          Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 15          Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 16          HLS    AllPub  ...           0        0    NaN    NaN         NaN
# 17          Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 18          Lvl    AllPub  ...           0        0    NaN  MnPrv        Shed
# 19          Lvl    AllPub  ...           0        0    NaN   GdWo         NaN
# 20          Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 21          Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 22          Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 23          Bnk    AllPub  ...           0        0    NaN    NaN         NaN
# 24          Lvl    AllPub  ...           0        0    NaN   GdWo         NaN
# 25          Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 26          Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 27          Lvl    AllPub  ...         265        0    NaN    NaN         NaN
# 28          Lvl    AllPub  ...         224        0    NaN    NaN         NaN
# 29          Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# ..          ...       ...  ...         ...      ...    ...    ...         ...
# 570         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 571         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 572         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 573         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 574         Low    AllPub  ...           0        0    NaN    NaN         NaN
# 575         Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# 576         Lvl    AllPub  ...           0        0    NaN   GdWo         NaN
# 577         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 578         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 579         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 580         Bnk    AllPub  ...           0        0    NaN    NaN         NaN
# 581         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 582         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 583         Lvl    AllPub  ...          40        0    NaN    NaN         NaN
# 584         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 585         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 586         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 587         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 588         Lvl    AllPub  ...           0        0    NaN   GdWo         NaN
# 589         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 590         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 591         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 592         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 593         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 594         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 595         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 596         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 597         Lvl    AllPub  ...           0        0    NaN  GdPrv        Shed
# 598         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 599         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         0      6    2007        WD         Normal
# 1         0      4    2010        WD         Normal
# 2         0      5    2010        WD         Normal
# 3         0      7    2009        WD         Normal
# 4         0      5    2008       New        Partial
# 5         0      8    2009        WD         Normal
# 6         0     11    2007       New        Partial
# 7       400      5    2007        WD         Normal
# 8         0      5    2006        WD         Normal
# 9         0      6    2010        WD         Normal
# 10        0      8    2009        WD         Normal
# 11        0      6    2010        WD         Normal
# 12        0     10    2008        WD         Normal
# 13        0      9    2009        WD         Normal
# 14        0      8    2009        WD        Abnorml
# 15        0      8    2007       New        Partial
# 16        0      1    2007        WD         Normal
# 17        0      6    2009        WD         Normal
# 18      400      6    2010        WD         Normal
# 19        0      7    2009        WD         Normal
# 20        0      6    2007        WD         Normal
# 21        0      4    2007        WD         Normal
# 22        0     12    2009        WD         Normal
# 23        0      3    2006        WD         Normal
# 24        0      7    2009        WD         Normal
# 25        0      1    2008       CWD        Abnorml
# 26        0      6    2006        WD         Family
# 27        0      4    2008        WD         Normal
# 28        0     10    2007        WD         Normal
# 29        0      2    2009        WD         Normal
# ..      ...    ...     ...       ...            ...
# 570       0      7    2006        WD         Normal
# 571       0     10    2009        WD         Normal
# 572       0      8    2007        WD         Normal
# 573       0      5    2008        WD         Normal
# 574       0      5    2006        WD         Normal
# 575       0      7    2008       COD        Abnorml
# 576       0      5    2007        WD         Normal
# 577       0     11    2008       New        Partial
# 578       0      4    2010        WD         Normal
# 579       0     11    2007        WD         Normal
# 580       0      9    2008        WD         Normal
# 581       0      5    2008        WD         Normal
# 582       0      4    2009        WD         Normal
# 583       0      5    2009        WD         Normal
# 584       0     11    2007        WD         Normal
# 585       0      5    2007        WD         Normal
# 586       0      4    2010        WD         Normal
# 587       0     12    2007        WD         Normal
# 588       0      5    2007        WD         Normal
# 589       0      8    2006        WD        Abnorml
# 590       0      9    2009        WD         Normal
# 591       0      5    2009       New        Partial
# 592       0      5    2006        WD         Normal
# 593       0      7    2006        WD        Abnorml
# 594       0     10    2009        WD         Normal
# 595       0      8    2007        WD         Normal
# 596       0      2    2010        WD         Normal
# 597    2500      5    2010        WD         Normal
# 598       0      4    2010        WD         Normal
# 599       0      6    2008        WD         Normal
#
# [600 rows x 80 columns]

# %%
#check the numbers of samples and features
print("The train data size before dropping Id feature is : {} ".format(train.shape))
print("The test data size before dropping Id feature is : {} ".format(test.shape))

#Save the 'Id' column
train_ID = train['Id']
test_ID = test['Id']

#Now drop the  'Id' colum since it's unnecessary for  the prediction process.
train.drop("Id", axis = 1, inplace = True)
test.drop("Id", axis = 1, inplace = True)

#check again the data size after dropping the 'Id' variable
print("\nThe train data size after dropping Id feature is : {} ".format(train.shape)) 
print("The test data size after dropping Id feature is : {} ".format(test.shape))
# Out:
# The train data size before dropping Id feature is : (860, 81)
# The test data size before dropping Id feature is : (600, 80)
#
# The train data size after dropping Id feature is : (860, 80)
# The test data size after dropping Id feature is : (600, 79)

# %% [markdown]
# # <span style="color:blue"> Data Processing 전처리 같이 해봅시다

# %%
fig, ax = plt.subplots()
ax.scatter(x = train['GrLivArea'], y = train['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %% [markdown]
# **Q1. 위 그림에서 이상치로 판단되는 데이터를 제거하시오.**
#
# **사람마다 기준은 다르나 저는 오른쪽 따로노는 아이가 이상하군요....?**

# %%
#Deleting outliers
train = train.query('GrLivArea<4500')

#Check the graphic again
fig, ax = plt.subplots()
ax.scatter(train['GrLivArea'], train['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %% [markdown]
# ## Features engineering

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
y_train = train.SalePrice.values
all_data = pd.concat((train, test)).reset_index(drop=True)
all_data.drop(['SalePrice'], axis=1, inplace=True)
print("all_data size is : {}".format(all_data.shape))
# Out:
# all_data size is : (1459, 79)

# %% [markdown]
# ### Missing Data

# %%
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head(20)
# Out:
#               Missing Ratio
# PoolQC            99.520219
# MiscFeature       96.298835
# Alley             93.762851
# Fence             80.740233
# FireplaceQu       47.292666
# LotFrontage       17.751885
# GarageYrBlt        5.551748
# GarageType         5.551748
# GarageQual         5.551748
# GarageFinish       5.551748
# GarageCond         5.551748
# BsmtFinType2       2.604524
# BsmtExposure       2.604524
# BsmtQual           2.535984
# BsmtFinType1       2.535984
# BsmtCond           2.535984
# MasVnrArea         0.548321
# MasVnrType         0.548321
# Electrical         0.068540

# %%
f, ax = plt.subplots(figsize=(15, 12))
plt.xticks(rotation='90')
sns.barplot(x=all_data_na.index, y=all_data_na)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percent missing data by feature')

# %% [markdown]
# **Data Correlation**

# %%
#Correlation map to see how features are correlated with SalePrice
corrmat = train.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.9, square=True)

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# **Q3.결측치를 None으로 바꿔봅시다**
# **그냥 바꾸지만 마시고 왜 None으로 바꾸는지 한번 생각해보세요**

# %% [markdown]
# - **PoolQC** : data description says NA means "No  Pool". That make sense, given the huge ratio of missing value (+99%) and majority of houses have no Pool at all in general.
#
# - 데이터 설명에 NA 는 no pool을 의미한다.
# - 99%의 비율, 주택에는 일반적으로 수영장이 없기때문에 이해가 된다.

# %%
all_data["PoolQC"] = all_data["PoolQC"].fillna("None")

# %% [markdown]
# - **MiscFeature** : data description says NA means "no misc feature"
#
# - 기타기능 없음

# %%
all_data["MiscFeature"] = all_data["MiscFeature"].fillna("None")

# %% [markdown]
# - **Alley** : data description says NA means "no alley access"
#
# - 골목 접근금지

# %%
all_data["Alley"] = all_data["Alley"].fillna("None")

# %% [markdown]
# - **Fence** : data description says NA means "no fence"

# %%
all_data["Fence"] = all_data["Fence"].fillna("None")

# %% [markdown]
# - **FireplaceQu** : data description says NA means "no fireplace"
#
# - 난로 없음

# %%
all_data["FireplaceQu"] = all_data["FireplaceQu"].fillna("None")

# %% [markdown]
# - **LotFrontage** :

# %% [markdown]
#  **Q4. the area of each street connected to the house property most likely have a similar area to other houses in its neighborhood. 인 변수입니다. 그러면 결측치를 어떻게 바꾸는게 좋을까요?**
#
# - 주택 속성에 연결된 각 거리의 면적은 해당 지역의 다른 주택과 비슷한 지역일 가능성이 높다

# %%
all_data["LotFrontage"]
# Out:
# 0        65.0
# 1        80.0
# 2        68.0
# 3        60.0
# 4        84.0
# 5        85.0
# 6        75.0
# 7         NaN
# 8        51.0
# 9        50.0
# 10       70.0
# 11       85.0
# 12        NaN
# 13       91.0
# 14        NaN
# 15       51.0
# 16        NaN
# 17       72.0
# 18       66.0
# 19       70.0
# 20      101.0
# 21       57.0
# 22       75.0
# 23       44.0
# 24        NaN
# 25      110.0
# 26       60.0
# 27       98.0
# 28       47.0
# 29       60.0
#         ...
# 1429     60.0
# 1430      NaN
# 1431     60.0
# 1432     93.0
# 1433     80.0
# 1434     80.0
# 1435     60.0
# 1436     96.0
# 1437     90.0
# 1438     80.0
# 1439     79.0
# 1440      NaN
# 1441     85.0
# 1442      NaN
# 1443     63.0
# 1444     70.0
# 1445      NaN
# 1446     80.0
# 1447     70.0
# 1448     21.0
# 1449     60.0
# 1450     78.0
# 1451     35.0
# 1452     90.0
# 1453     62.0
# 1454     62.0
# 1455     85.0
# 1456     66.0
# 1457     68.0
# 1458     75.0
# Name: LotFrontage, Length: 1459, dtype: float64

# %%
# 평균값으로 결측치 채우기

all_data["LotFrontage"] = all_data.groupby("Neighborhood")["LotFrontage"].transform(
    lambda x: x.fillna(x.median()))

# %% [markdown]
# - **Q5. GarageType, GarageFinish, GarageQual and GarageCond** : Replacing missing data with None

# %%
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    all_data[col] = all_data[col].fillna('None')

# %% [markdown]
# - **Q6. GarageYrBlt, GarageArea and GarageCars** : Replacing missing data with 0 (Since No garage = no cars in such garage.)
#
# - 차고 없음.

# %%
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
    all_data[col] = all_data[col].fillna(0)

# %% [markdown]
# - **Q7. BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, BsmtFullBath and BsmtHalfBath** : missing values are likely zero for having no basement
#
# - 지하실이 없으면 결측값이 0일 가능성이 높다.

# %%
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    all_data[col] = all_data[col].fillna(0)

# %% [markdown]
# - **Q8. BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1 and BsmtFinType2** : For all these categorical basement-related features, NaN means that there is no  basement.

# %%
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    all_data[col] = all_data[col].fillna('None')

# %% [markdown]
# - **Q9. MasVnrArea and MasVnrType** : NA most likely means no masonry veneer for these houses. We can fill 0 for the area and None for the type.

# %%
all_data["MasVnrType"] = all_data["MasVnrType"].fillna("None")
all_data["MasVnrArea"] = all_data["MasVnrArea"].fillna(0)

# %% [markdown]
# - **MSZoning (The general zoning classification)** :  'RL' is by far  the most common value.  So we can fill in missing values with 'RL'
#
# - RL'이 가장 일반적인 값입니다. 따라서 'RL'로 결 측값을 채울 수 있습니다.
#
# - **Q10. MSZoning에서 가장 많이 존재하는 값으로 결측치를 대체하세요**

# %%
all_data['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
all_data['MSZoning'].mode()
# Out:
# 0    RL
# dtype: object

# %%
all_data['MSZoning'] = all_data['MSZoning'].fillna(all_data['MSZoning'].mode()[0])

# %% [markdown]
# - **Utilities** : For this categorical feature all records are "AllPub", except for one "NoSeWa"  and 2 NA . Since the house with 'NoSewa' is in the training set, **this feature won't help in predictive modelling**. We can then safely  remove it.
#
#
# -"NoSeWa"및 2 NA를 제외한 모든 레코드는 "AllPub"입니다.
# - 제거해 버리자!

# %%
all_data['Utilities'].value_counts()
# Out:
# AllPub    1458
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
all_data = all_data.drop(['Utilities'], axis=1)

# %% [markdown]
# - **Functional** : data description says NA means typical

# %%
all_data["Functional"] = all_data["Functional"].fillna("Typ")

# %% [markdown]
# - **Electrical** : It has one NA value. Since this feature has mostly 'SBrkr', we can set that for the missing value.

# %% [markdown]
# **Q11.  가장 많이 존재하는 값으로 결측치를 대체하세요**

# %%
all_data['Electrical'] = all_data['Electrical'].fillna(all_data['Electrical'].mode()[0])

# %% [markdown]
# - **KitchenQual**: Only one NA value, and same as Electrical, we set 'TA' (which is the most frequent)  for the missing value in KitchenQual.

# %%
all_data['KitchenQual'] = all_data['KitchenQual'].fillna(all_data['KitchenQual'].mode()[0])

# %% [markdown]
# - **Exterior1st and Exterior2nd** : Again Both Exterior 1 & 2 have only one missing value. We will just substitute in the most common string

# %%
all_data['Exterior1st'] = all_data['Exterior1st'].fillna(all_data['Exterior1st'].mode()[0])
all_data['Exterior2nd'] = all_data['Exterior2nd'].fillna(all_data['Exterior2nd'].mode()[0])

# %% [markdown]
# - **SaleType** : Fill in again with most frequent which is "WD"

# %%
all_data['SaleType'] = all_data['SaleType'].fillna(all_data['SaleType'].mode()[0])

# %% [markdown]
# - **MSSubClass** : Na most likely means No building class. We can replace missing values with None

# %%
all_data['MSSubClass'] = all_data['MSSubClass'].fillna("None")

# %% [markdown]
# Is there any remaining missing value ?

# %%
#Check remaining missing values if any 
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head()
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %% [markdown]
# ### More features engeneering

# %% [markdown]
# **Transforming some numerical variables that are really categorical**
#
# 숫자형태를 한 값일 뿐 실제 연속형도 숫자 데이터도 아니죠? 따라서 문자형식으로 바꾼후 라벨링 인코더 하겠습니다.

# %% [markdown]
# **Q12. 데이터를 문자형으로 바꾸세요.**

# %%
all_data['MSSubClass']
# Out:
# 0        60
# 1        20
# 2        60
# 3        70
# 4        60
# 5        50
# 6        20
# 7        60
# 8        50
# 9       190
# 10       20
# 11       60
# 12       20
# 13       20
# 14       20
# 15       45
# 16       20
# 17       90
# 18       20
# 19       20
# 20       60
# 21       45
# 22       20
# 23      120
# 24       20
# 25       20
# 26       20
# 27       20
# 28       20
# 29       30
#        ...
# 1429     60
# 1430    120
# 1431     30
# 1432     60
# 1433     20
# 1434     20
# 1435     20
# 1436     20
# 1437     20
# 1438     60
# 1439     70
# 1440    120
# 1441     60
# 1442     30
# 1443     20
# 1444     85
# 1445     20
# 1446     60
# 1447     50
# 1448    180
# 1449     90
# 1450     20
# 1451    180
# 1452     20
# 1453     20
# 1454     60
# 1455     20
# 1456     70
# 1457     20
# 1458     20
# Name: MSSubClass, Length: 1459, dtype: int64

# %%
all_data['OverallCond']
# Out:
# 0       5
# 1       8
# 2       5
# 3       5
# 4       5
# 5       5
# 6       5
# 7       6
# 8       5
# 9       6
# 10      5
# 11      5
# 12      6
# 13      5
# 14      5
# 15      8
# 16      7
# 17      5
# 18      5
# 19      6
# 20      5
# 21      7
# 22      5
# 23      7
# 24      8
# 25      5
# 26      7
# 27      5
# 28      6
# 29      6
#        ..
# 1429    5
# 1430    6
# 1431    6
# 1432    5
# 1433    5
# 1434    9
# 1435    6
# 1436    5
# 1437    7
# 1438    6
# 1439    7
# 1440    5
# 1441    5
# 1442    6
# 1443    5
# 1444    5
# 1445    7
# 1446    5
# 1447    7
# 1448    7
# 1449    5
# 1450    5
# 1451    5
# 1452    5
# 1453    5
# 1454    5
# 1455    6
# 1456    9
# 1457    6
# 1458    6
# Name: OverallCond, Length: 1459, dtype: int64

# %%
#MSSubClass=The building class
all_data['MSSubClass'] = all_data['MSSubClass'].apply(str)


#Changing OverallCond into a categorical variable
all_data['OverallCond'] = all_data['OverallCond'].astype(str)


#Year and month sold are transformed into categorical features.
all_data['YrSold'] = all_data['YrSold'].astype(str)
all_data['MoSold'] = all_data['MoSold'].astype(str)

# %% [markdown]
# **Label Encoding some categorical variables that may contain information in their ordering set**

# %% [markdown]
# **Q13. LabelEncoder로 해당 범주형 데이터를 바꿔보세요..**

# %% [markdown]
# LabelEncoder 객체를 생성하고, 수치화 시키고자 하는 field를 해당 객체를 통해서 변형시키면 된다.

# %%
from sklearn.preprocessing import LabelEncoder
cols = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')

for i in cols:
    lbl = LabelEncoder() 
    lbl.fit(list(all_data[i].values)) 
    all_data[i] = lbl.transform(list(all_data[i].values))

# shape        
print('Shape all_data: {}'.format(all_data.shape))
# Out:
# Shape all_data: (1459, 78)

# %% [markdown]
# **Adding one more important feature**

# %%
# Adding total sqfootage feature 
all_data['TotalSF'] = all_data['TotalBsmtSF'] + all_data['1stFlrSF'] + all_data['2ndFlrSF']

# %% [markdown]
# **Skewed features**

# %%
numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index

skewed_feats = all_data[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in numerical features: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness.head(10)
# Out:
# Skew in numerical features:
#                    Skew
# MiscVal       24.443278
# PoolArea      14.807992
# LotArea       12.290047
# 3SsnPorch     10.290132
# LowQualFinSF   8.998885
# LandSlope      4.806884
# KitchenAbvGr   4.482026
# BsmtFinSF2     4.249219
# ScreenPorch    4.116334
# BsmtHalfBath   4.097541

# %% [markdown]
# **Box Cox Transformation of (highly) skewed features**

# %% [markdown]
# We use the scipy  function boxcox1p which computes the Box-Cox transformation of **\\(1 + x\\)**.
#
# Note that setting \\( \lambda = 0 \\) is equivalent to log1p used above for the target variable.
#
# See [this page][1] for more details on Box Cox Transformation as well as [the scipy function's page][2]
# [1]: http://onlinestatbook.com/2/transformations/box-cox.html
# [2]: https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.special.boxcox1p.html

# %%
skewness = skewness[abs(skewness) > 0.75]


from scipy.special import boxcox1p
skewed_features = skewness.index
lam = 0.15
for feat in skewed_features:
    all_data[feat] = boxcox1p(all_data[feat], lam)

# %% [markdown]
# **Getting dummy categorical features**

# %% [markdown]
# **Q14. 더미화하세요.**

# %%
all_data = pd.get_dummies(all_data)  
print(all_data.shape)
# Out:
# (1459, 220)

# %% [markdown]
# Getting the new train and test sets.

# %%
train = all_data[:ntrain]
test = all_data[ntrain:]

# %% [markdown]
# #Modelling

# %% [markdown]
# # <span style="color:blue"> 이 아래부터의 과정은 앙상블을 정말 모르겠다.(코드) 그런 분들을 위해 참조용으로 있을 뿐. 알아서 하셔도 무방합니다.

# %% [markdown]
# **Import librairies**

# %%
! pip install xgboost
# Out:
# Collecting xgboost
#   Downloading https://files.pythonhosted.org/packages/5e/49/b95c037b717b4ceadc76b6e164603471225c27052d1611d5a2e832757945/xgboost-0.90-py2.py3-none-win_amd64.whl (18.3MB)
# Requirement already satisfied: scipy in c:\users\misung\anaconda3\lib\site-packages (from xgboost) (1.2.1)
# Requirement already satisfied: numpy in c:\users\misung\anaconda3\lib\site-packages (from xgboost) (1.16.4)
# Installing collected packages: xgboost
# Successfully installed xgboost-0.90

# %%
 ! pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading https://files.pythonhosted.org/packages/1f/cb/a8ec24334c35a7d0c87b4e4e056bd2137573c7c1bd81c760b79a2f370254/lightgbm-2.3.1-py2.py3-none-win_amd64.whl (544kB)
# Requirement already satisfied: numpy in c:\users\misung\anaconda3\lib\site-packages (from lightgbm) (1.16.4)
# Requirement already satisfied: scipy in c:\users\misung\anaconda3\lib\site-packages (from lightgbm) (1.2.1)
# Requirement already satisfied: scikit-learn in c:\users\misung\anaconda3\lib\site-packages (from lightgbm) (0.21.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\misung\anaconda3\lib\site-packages (from scikit-learn->lightgbm) (0.13.2)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-2.3.1

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# %% [markdown]
# **Define a cross validation strategy**

# %% [markdown]
# We use the **cross_val_score** function of Sklearn. However this function has not a shuffle attribut, we add then one line of code,  in order to shuffle the dataset  prior to cross-validation
#
#
# - 우리는 Sklearn의 cross_val_score 함수를 사용합니다. 그러나이 함수는 셔플 속성이 없으므로 교차 유효성 검사 전에 데이터 세트를 셔플하기 위해 한 줄의 코드를 추가합니다

# %%
#Validation function  검증을 하기 위한 함수
n_folds = 5

def rmsle_cv(model):
    
    #데이터를 섞어주고
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
    
    # 검사 
    rmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %% [markdown]
# ##Base models

# %% [markdown]
# -  **LASSO  Regression**  :
#
# This model may be very sensitive to outliers. So we need to made it more robust on them. For that we use the sklearn's  **Robustscaler()**  method on pipeline
#
#
# - 특이값에 민감할수 있다. 그래서 더 강하게 만들어야하고, Robustscaler를 추가해줌.
#
# - Least Absolute Shrinkage Selector Operator
#
# - lasso 는 중요한 몇개의 변수만 선택하고 다른 계수들은 0으로 줄인다.
# > feature selection을 한다.

# %%
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))

# %% [markdown]
# - **Elastic Net Regression** :
#
# again made robust to outliers
#
# - 또 다른 유형의 regression .
# - Ridge 와 Lasso의 하이브리드 형태
# - 큰 데이터 셋에서 가장 잘 작동한다.

# %%
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))

# %% [markdown]
# - **Kernel Ridge Regression** :

# %%
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)

# %% [markdown]
# - **Gradient Boosting Regression** :
#
# With **huber**  loss that makes it robust to outliers

# %% [markdown]
# - n_estimators  : Gradient boosting is fairly robust to over-fitting
#                 so a large number usually results in better performance.
#
# - max_depth : 트리의 노드 수를 제한한다.
#
# - max_features : 최상의 분할을 찾을때 고려해야할 수
#                 If “sqrt”, then max_features=sqrt(n_features).
#
# - The minimum number of samples required to be at a leaf node.

# %%
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)

# %% [markdown]
# - **XGBoost** :

# %%
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

# %% [markdown]
# - **LightGBM** :

# %%
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

# %% [markdown]
# ### Base models scores

# %% [markdown]
# cross-validation rmsle error로 모델 성능을 확인해 봅시다

# %%
score = rmsle_cv(lasso)
print("\nLasso score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Lasso score: 0.1179 (0.0121)

# %%
score = rmsle_cv(ENet)
print("ElasticNet score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# ElasticNet score: 0.1183 (0.0123)

# %%
score = rmsle_cv(KRR)
print("Kernel Ridge score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Kernel Ridge score: 0.1252 (0.0136)

# %%
score = rmsle_cv(GBoost)
print("Gradient Boosting score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Gradient Boosting score: 0.1231 (0.0127)

# %%
score = rmsle_cv(model_xgb)
print("Xgboost score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Xgboost score: 0.1237 (0.0085)

# %%
score = rmsle_cv(model_lgb)
print("LGBM score: {:.4f} ({:.4f})\n" .format(score.mean(), score.std()))
# Out:
# LGBM score: 0.1245 (0.0101)

# %% [markdown]
# ##Stacking  models

# %% [markdown]
# ###Simplest Stacking approach : Averaging base models

# %% [markdown]
# **Averaged base models class**

# %%
class AveragingModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, models):
        self.models = models
        
    # we define clones of the original models to fit the data in
    def fit(self, X, y):
        self.models_ = [clone(x) for x in self.models]
        
        # Train cloned base models
        for model in self.models_:
            model.fit(X, y)

        return self
    
    #Now we do the predictions for cloned models and average them
    def predict(self, X):
        predictions = np.column_stack([model.predict(X) for model in self.models_])
        return np.mean(predictions, axis=1)

# %% [markdown]
# **Averaged base models score**

# %%
averaged_models = AveragingModels(models = (lasso, ENet, KRR, GBoost, model_xgb, model_lgb))

score = rmsle_cv(averaged_models)
print(" Averaged base models score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
#  Averaged base models score: 0.1135 (0.0115)

# %% [markdown]
# ###Less simple Stacking : Adding a Meta-model

# %% [markdown]
# In this approach, we add a meta-model on averaged base models and use the out-of-folds predictions of these base models to train our meta-model.
#
# The procedure, for the training part, may be described as follows:
#
#
# 1. Split the total training set into two disjoint sets (here **train** and .**holdout** )
#
# 2. Train several base models on the first part (**train**)
#
# 3. Test these base models on the second part (**holdout**)
#
# 4. Use the predictions from 3)  (called  out-of-folds predictions) as the inputs, and the correct responses (target variable) as the outputs  to train a higher level learner called **meta-model**.
#
# The first three steps are done iteratively . If we take for example a 5-fold stacking , we first split the training data into 5 folds. Then we will do 5 iterations. In each iteration,  we train every base model on 4 folds and predict on the remaining fold (holdout fold).
#
# So, we will be sure, after 5 iterations , that the entire data is used to get out-of-folds predictions that we will then use as
# new feature to train our meta-model in the step 4.
#
# For the prediction part , We average the predictions of  all base models on the test data  and used them as **meta-features**  on which, the final prediction is done with the meta-model.

# %% [markdown]
# ![Faron](http://i.imgur.com/QBuDOjs.jpg)
#
# (Image taken from [Faron](https://www.kaggle.com/getting-started/18153#post103381))

# %% [markdown]
# On this gif, the base models are algorithms 0, 1, 2 and the meta-model is algorithm 3. The entire training dataset is
# A+B (target variable y known) that we can split into train part (A) and holdout part (B). And the test dataset is C.
#
# B1 (which is the prediction from the holdout part)  is the new feature used to train the meta-model 3 and C1 (which
# is the prediction  from the test dataset) is the meta-feature on which the final prediction is done.

# %% [markdown]
# **Stacking averaged Models Class**

# %%
class StackingAveragedModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, base_models, meta_model, n_folds=5):
        self.base_models = base_models
        self.meta_model = meta_model
        self.n_folds = n_folds
   
    # We again fit the data on clones of the original models
    def fit(self, X, y):
        self.base_models_ = [list() for x in self.base_models]
        self.meta_model_ = clone(self.meta_model)
        kfold = KFold(n_splits=self.n_folds, shuffle=True, random_state=156)
        
        # Train cloned base models then create out-of-fold predictions
        # that are needed to train the cloned meta-model
        out_of_fold_predictions = np.zeros((X.shape[0], len(self.base_models)))
        for i, model in enumerate(self.base_models):
            for train_index, holdout_index in kfold.split(X, y):
                instance = clone(model)
                self.base_models_[i].append(instance)
                instance.fit(X[train_index], y[train_index])
                y_pred = instance.predict(X[holdout_index])
                out_of_fold_predictions[holdout_index, i] = y_pred
                
        # Now train the cloned  meta-model using the out-of-fold predictions as new feature
        self.meta_model_.fit(out_of_fold_predictions, y)
        return self
   
    #Do the predictions of all base models on the test data and use the averaged predictions as 
    #meta-features for the final prediction which is done by the meta-model 
    def predict(self, X):
        meta_features = np.column_stack([
            np.column_stack([model.predict(X) for model in base_models]).mean(axis=1)
            for base_models in self.base_models_ ])
        return self.meta_model_.predict(meta_features)

# %% [markdown]
# **Stacking Averaged models Score**

# %% [markdown]
# weak learners : base model
# 최종적으로 학습을 시키는 모델이 meta_model

# %%
stacked_averaged_models = StackingAveragedModels(base_models = (ENet,GBoost, KRR),
                                                 meta_model = lasso)

score = rmsle_cv(stacked_averaged_models)                 
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# Stacking Averaged models score: 0.1133 (0.0118)

# %%
stacked_averaged_models2 = StackingAveragedModels(base_models = (ENet,GBoost, KRR),
                                                 meta_model = model_lgb)

score2 = rmsle_cv(stacked_averaged_models2)                 
print("Stacking Averaged models2 score2: {:.4f} ({:.4f})".format(score2.mean(), score2.std()))
# Out:
# Stacking Averaged models2 score2: 0.1230 (0.0128)

# %%
stacked_averaged_models3 = StackingAveragedModels(base_models = (lasso,model_xgb, KRR),
                                                 meta_model = model_lgb)

score3 = rmsle_cv(stacked_averaged_models3)                 
print("Stacking Averaged models2 score2: {:.4f} ({:.4f})".format(score3.mean(), score3.std()))
# Out:
# Stacking Averaged models2 score2: 0.1260 (0.0112)

# %% [markdown]
# StackingAveragedModel 의 확률이 더 좋게 나온다.

# %%
def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %% [markdown]
# ### Final Training and Prediction

# %% [markdown]
# **StackedRegressor:**

# %%
stacked_averaged_models.fit(train.values, y_train)
stacked_train_pred = stacked_averaged_models.predict(train.values)
stacked_pred = stacked_averaged_models.predict(test.values)
print(rmsle(y_train, stacked_train_pred))
# Out:
# 0.07242660654579812

# %%
stacked_averaged_models2.fit(train.values, y_train)
stacked_train_pred2 = stacked_averaged_models2.predict(train.values)
stacked_pred2 = stacked_averaged_models2.predict(test.values)
print(rmsle(y_train, stacked_train_pred2))
# Out:
# 0.08645076684415583

# %%
stacked_averaged_models3.fit(train.values, y_train)
stacked_train_pred3 = stacked_averaged_models3.predict(train.values)
stacked_pred3 = stacked_averaged_models3.predict(test.values)
print(rmsle(y_train, stacked_train_pred3))
# Out:
# 0.09408556181885726

# %%
# XGBoost
model_xgb.fit(train, y_train)
xgb_train_pred = model_xgb.predict(train)
xgb_pred = np.expm1(model_xgb.predict(test))
print('xgboost:', rmsle(y_train, xgb_train_pred))
# Out:
# [model]  xgboost: 0.08021078949311004

# %%
 # LightGBM
model_lgb.fit(train, y_train)
lgb_train_pred = model_lgb.predict(train)
lgb_pred = np.expm1(model_lgb.predict(test.values))
print( 'LightGBMs:', rmsle(y_train, lgb_train_pred))
# Out:
# LightGBMs: 0.06155322851692823

# %% [markdown]
# #같은 방식으로 여러 모델을 학습하고 예측값을 뺴보세요.

# %%
'''RMSE on the entire Train data when averaging'''

print('RMSLE score on train data:')
print(rmsle(y_train, stacked_train_pred*0.70 + xgb_train_pred*0.15 + lgb_train_pred*0.15  )) # 예측값을 앙상블 가중합한 값과 rmse값을 봐보자!
# Out:
# RMSLE score on train data:
# 0.06964463314119698

# %% [markdown]
# **Ensemble prediction:**

# %%
ensemble = stacked_pred3

# %% [markdown]
# **Submission**

# %%
sub = pd.DataFrame()
sub['Id'] = test_ID
sub['SalePrice'] = ensemble
sub.to_csv('submission.csv',index=False)
