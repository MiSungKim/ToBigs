# %% [markdown]
# 1. 파일로 제공되는 정형 데이터가 아닌 크롤링 으로 데이터를 수집해주세요
# 2. 임베딩 모델을 2 개 이상 적용해본 후 , Step5 의 결과에 따라 가장 좋은 모델을 선택해주세요 (ex) CBOW, Skip gram, GloVe , NN, FastText 등
# 3. RNN, LSTM 등 모델링을 하는 것이 아니기 때문에 이번 과제에서는 텍스트를 전처리, 토크나이징 , 임베딩 후 인사이트를 도출하는 경험 이 중요합니다. 주석 꼭 꼼꼼하게 달아주시고 데이터가 자유인만큼 참신한 인사이트 찾아주세요

# %% [markdown]
# ### 관심주제 : 영화 네티즌 리뷰를 크롤링해서 1917 영화에 대해 어떻게 생각하고 있는지 분석해보자.......!
#
# 시행착오 : 처음에 yes24에서 책 리뷰를 크롤링 하려했는데,,, 왜 안되는지 모르겠는데 실패함..
# 전체로 긁어와도 그 안에 리뷰가 안담겨있음... 왜지?

# %% [markdown]
# ### 1. 크롤링
#
# 한페이지당 10개, 10page에 속한 리뷰를 가져오자

# %%
# crawling

import requests
from urllib.request import Request,urlopen
from bs4 import BeautifulSoup
import re

# %%
url ='https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=187321&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page='
page = int(1)
ment = []
for i in range(10):
        open=urlopen(url+str(page))
        #print(URL)
        html=open.read().decode('utf-8')
        soup = BeautifulSoup(html,"lxml")
        list = soup.body.find(class_="score_result").find_all('li')
        
        for i in range(10):
            ment.append(list[i].find(class_="score_reple").find('p').text.strip())
            
        page+=1
print(ment)
# Out:
# ['관람객\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t이 영화는 미쳤다. 넷플릭스가 일상화된 시대에 극장이 존재해야하는 이유를 증명해준다.', '충무로: 이거 어케하는거냐?', '관람객\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t아카데미에서 촬영상, 음향효과상, 시각효과상을 받은 이유가 고스란히 녹아있는 영화. IMAX로 관람하는걸 추천한다.', '관람객\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t처절한 전쟁 속에서, 한 남자를 영웅으로 만든 것은 훈장도 장군의 명령도 아닌 바로 옆 전우였다.', '촬영감독의 영혼까지 갈아넣은 마스터피스', '오스카 작품상 탔어도 할말 없었을것 같다.', '주인공을 카메라가 계속 따라가는데.. 세트장이 엄청 넓은거에 놀랐습니다. 직접 1차대전에 참전하는 느낌.. 이때당시 군인들 20년뒤 히틀러라는 극악의 악마로 자식들 다 전장에 몰리고 더 최악의 고통을 받을껀데 참.....', '관람객\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t관객을 1917년 4월 6일로 데려놓는 마법같은 작품', '닥터스트레인지의 판단력이 좋았다.', '아카데미 작품상이야 작품전체를 보는거니 기생충이 받을수도 있다고 보는데 감독상은 1917 줬어도 할말 없음. 감독의 참신성이 빛을 발함. 결론적으로 아카데미 작품상과 감독상을 1917이 받았어도 아무 할말 없는 것이...', '관람객\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t앞으로 유사한 영화가 나올때마다 회자될 작품. 특히 원테이크로 보이게 하는 촬영과 연출은 봐도봐도 놀랍다.', '솔직히 연출력만으로 최고의 영화다. 마치 우리가 투명인간이 되서 그들을 지켜보는 듯했다. 마지막장면은 영화 내내 쉴시간이 없었던것에 대한 피로감을 풀어줘서 기승전결도 완벽.', '스포일러가 포함된 감상평입니다. 감상평 보기\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t노래 쳐 안듣고 뛰어갔으면 80명은 더 살렸겠다', '솔직히 나는 기생충보다 이영화가 더 재미있었다.', '진짜 원테이크 장면 너무 긴거 아님?? 촬영하기 진짜 힘들었을 듯...', '막판에 횡으로 수많은 병사가 신호와 함께 우르르 튀어나올때 주인공 혼자 종으로 막 달리는 장면 와 진짜ㅋㅋㅋㅋ대박 무조건 아이맥스로 보세요!', '관람객\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t온힘을 다해 뛸때 울컥한다. 인생작 리스트에 하나 추가', '관람객\n\n\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t오랜만에 영화란 극장에서 보는 것이라는 느낌을 갖게 해 준 명작. 카메라의 움직임, 배우의 감정, 360도로 전쟁이라는 공간, 주인공에게 주어진 미션과 여정. 그 모든 것이 완벽하게 짜여진 영화. 정말 좋은 영화다....', '원테이크 촬영신은 볼때마다 대단하다 후보에 오를만 했음', '스포일러가 포함된 감상평입니다. 감상평 보기\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t수많은 난관을 거치고 거쳐 도달한 곳은 결국 시작과 똑같은 풀밭 속 나무기둥 옆. 전쟁은 여전히 계속되고 있지만, 햇살이 그를 위로하듯이 드리운다.', '관람객\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t영화가 보통  컷트 컷트로 찍는게 대부분인데ㅡ이영화는 한컷으로 촬영한거 같다.ㅡ리얼 그장소에 내가 있는거 처럼 느껴졋고 끝까지 긴장감을 늦출 수 없다.', '일단..극장에서 보는걸  추천드립니다.카메라감독 상 줘야 할판  엄청나게  잘 찍음', '솔직히 샘 멘데스 감독 좀 억울할듯기생충도 재밌게 봤지만, 이거 보고나서 좀 억울했겠다는 생각이 팍듬..', '관람객\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t상 많이 받았다길래 기대하고 본 영화인데 진짜 최고!!지루하지않고 끝까지 시간가는줄 모르고 본영화음악땜에 더 긴장하고 조마조마했음', '동료를 잃고 목숨을 잃을 위기를 극복해나가며 달려 얻은 것은 전쟁의 무의미함과 허무함 뿐.', '이 모든 것이 하루만의 일이라니...', '기생충이 그냥 백인이 나온 헐리우드 영화였다면 절대 1917을 이기지 못했을것. 1917은 오히려 백인의 헐리우드 영화라 차별받음. 진짜 근래 보기 드믄 명작', '전쟁이 끝나는 길은 마지막 한사람까지 죽는 것이다.', '관람객\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t전쟁영화의 마스터피스. 모든 것이 완벽한 영화.', '스포일러가 포함된 감상평입니다. 감상평 보기\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t야외에서 롱테이크 방식으로 찍는게 쉬운게 아닌데 그걸 해낸 엄청난 영화이고 주인공들의 감정을 잘 드러냄. 특히 마지막에 돌진하는 군인들과 다른 방향으로 뛰는 주인공의 모습은 굉장히 인상적임.', '전쟁씬 안나온다고 보지말라던 사람들 너무 한심하다', '관람객\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t진짜 스크린에서 눈을 뗄 수가 없다. 미친 몰입감에다가, 전쟁터에서 있는거처럼 몸에 힘 빡! 주고 보게 됨. 그리고 갑자기 끝에,, 눈물이 흘렀다. 예상하지 못한 감동이 울컥 올라와서 더 놀라운 영화.', '병사를 따라가다보면 경험할 전쟁의 참상과 자연스레 따라오는 두려움과 먹먹함, 이건 판타지를 제외한 영화의 기술이 구현할 수 있는 가장 최상의 리 ...

# %%
! pip install KoNLPy
# Out:
# Requirement already satisfied: KoNLPy in c:\users\misung\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: tweepy>=3.7.0 in c:\users\misung\anaconda3\lib\site-packages (from KoNLPy) (3.8.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\misung\anaconda3\lib\site-packages (from KoNLPy) (1.16.4)
# Requirement already satisfied: beautifulsoup4==4.6.0 in c:\users\misung\anaconda3\lib\site-packages (from KoNLPy) (4.6.0)
# Requirement already satisfied: colorama in c:\users\misung\anaconda3\lib\site-packages (from KoNLPy) (0.4.1)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\misung\anaconda3\lib\site-packages (from KoNLPy) (4.3.4)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\misung\anaconda3\lib\site-packages (from KoNLPy) (0.7.2)
# Requirement already satisfied: requests>=2.11.1 in c:\users\misung\anaconda3\lib\site-packages (from tweepy>=3.7.0->KoNLPy) (2.22.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\misung\anaconda3\lib\site-packages (from tweepy>=3.7.0->KoNLPy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\misung\anaconda3\lib\site-packages (from tweepy>=3.7.0->KoNLPy) (1.12.0)
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\misung\anaconda3\lib\site-packages (from tweepy>=3.7.0->KoNLPy) (1.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\misung\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy>=3.7.0->KoNLPy) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\misung\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy>=3.7.0->KoNLPy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\misung\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy>=3.7.0->KoNLPy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\misung\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy>=3.7.0->KoNLPy) (1.24.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\misung\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->KoNLPy) (3.1.0)

# %%
! pip install -U gensim
# Out:
# Requirement already up-to-date: gensim in c:\users\misung\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in c:\users\misung\anaconda3\lib\site-packages (from gensim) (1.10.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in c:\users\misung\anaconda3\lib\site-packages (from gensim) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in c:\users\misung\anaconda3\lib\site-packages (from gensim) (1.16.4)
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in c:\users\misung\anaconda3\lib\site-packages (from gensim) (1.12.0)
# Requirement already satisfied, skipping upgrade: google-cloud-storage in c:\users\misung\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (1.26.0)
# Requirement already satisfied, skipping upgrade: requests in c:\users\misung\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.22.0)
# Requirement already satisfied, skipping upgrade: boto3 in c:\users\misung\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (1.12.27)
# Requirement already satisfied, skipping upgrade: google-cloud-core<2.0dev,>=1.2.0 in c:\users\misung\anaconda3\lib\site-packages (from google-cloud-storage->smart-open>=1.8.1->gensim) (1.3.0)
# Requirement already satisfied, skipping upgrade: google-resumable-media<0.6dev,>=0.5.0 in c:\users\misung\anaconda3\lib\site-packages (from google-cloud-storage->smart-open>=1.8.1->gensim) (0.5.0)
# Requirement already satisfied, skipping upgrade: google-auth<2.0dev,>=1.11.0 in c:\users\misung\anaconda3\lib\site-packages (from google-cloud-storage->smart-open>=1.8.1->gensim) (1.11.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\misung\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2019.11.28)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\misung\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.24.2)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\users\misung\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\users\misung\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Requirement already satisfied, skipping upgrade: s3transfer<0.4.0,>=0.3.0 in c:\users\misung\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.3.3)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in c:\users\misung\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.9.5)
# Requirement already satisfied, skipping upgrade: botocore<1.16.0,>=1.15.27 in c:\users\misung\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (1.15.27)
# Requirement already satisfied, skipping upgrade: google-api-core<2.0.0dev,>=1.16.0 in c:\users\misung\anaconda3\lib\site-packages (from google-cloud-core<2.0dev,>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in c:\users\misung\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim) (41.0.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\users\misung\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim) (0.2.8)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in c:\users\misung\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim) (4.0.0)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in c:\users\misung\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim) (4.0)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in c:\users\misung\anaconda3\lib\site-packages (from botocore<1.16.0,>=1.15.27->boto3->smart-open>=1.8.1->gensim) (2.8.0)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in c:\users\misung\anaconda3\lib\site-packages (from botocore<1.16.0,>=1.15.27->boto3->smart-open>=1.8.1->gensim) (0.14)
# Requirement already satisfied, skipping upgrade: pytz in c:\users\misung\anaconda3\lib\site-packages (from google-api-core<2.0.0dev,>=1.16.0->google-cloud-core<2.0dev,>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim) (2019.1)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\misung\anaconda3\lib\site-packages (from google-api-core<2.0.0dev,>=1.16.0->google-cloud-core<2.0dev,>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim) (1.51.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.4.0 in c:\users\misung\anaconda3\lib\site-packages (from google-api-core<2.0.0dev,>=1.16.0->google-cloud-core<2.0dev,>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim) (3.9.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in c:\users\misung\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim) (0.4.8)

# %%
import numpy as np
import pandas as pd
from konlpy.tag import *
from gensim.models import Word2Vec, fasttext

# %% [markdown]
# ### 2. 전처리 , 특수문자 제거

# %%
# 필요없는 문자 제거
ment = "".join(ment)
ment = re.sub('[-=+.,#/(?!:$}]', '', ment)
ment = re.sub('\n', '', ment)
ment = re.sub('\t', '', ment)
ment = re.sub('\r', '', ment)
ment = re.sub('관람객', '', ment)
# ment = re.sub('[0-9]', '', ment)

ment
# Out:
# '이 영화는 미쳤다 넷플릭스가 일상화된 시대에 극장이 존재해야하는 이유를 증명해준다충무로 이거 어케하는거냐아카데미에서 촬영상 음향효과상 시각효과상을 받은 이유가 고스란히 녹아있는 영화 IMAX로 관람하는걸 추천한다처절한 전쟁 속에서 한 남자를 영웅으로 만든 것은 훈장도 장군의 명령도 아닌 바로 옆 전우였다촬영감독의 영혼까지 갈아넣은 마스터피스오스카 작품상 탔어도 할말 없었을것 같다주인공을 카메라가 계속 따라가는데 세트장이 엄청 넓은거에 놀랐습니다 직접 1차대전에 참전하는 느낌 이때당시 군인들 20년뒤 히틀러라는 극악의 악마로 자식들 다 전장에 몰리고 더 최악의 고통을 받을껀데 참관객을 1917년 4월 6일로 데려놓는 마법같은 작품닥터스트레인지의 판단력이 좋았다아카데미 작품상이야 작품전체를 보는거니 기생충이 받을수도 있다고 보는데 감독상은 1917 줬어도 할말 없음 감독의 참신성이 빛을 발함 결론적으로 아카데미 작품상과 감독상을 1917이 받았어도 아무 할말 없는 것이앞으로 유사한 영화가 나올때마다 회자될 작품 특히 원테이크로 보이게 하는 촬영과 연출은 봐도봐도 놀랍다솔직히 연출력만으로 최고의 영화다 마치 우리가 투명인간이 되서 그들을 지켜보는 듯했다 마지막장면은 영화 내내 쉴시간이 없었던것에 대한 피로감을 풀어줘서 기승전결도 완벽스포일러가 포함된 감상평입니다 감상평 보기노래 쳐 안듣고 뛰어갔으면 80명은 더 살렸겠다솔직히 나는 기생충보다 이영화가 더 재미있었다진짜 원테이크 장면 너무 긴거 아님 촬영하기 진짜 힘들었을 듯막판에 횡으로 수많은 병사가 신호와 함께 우르르 튀어나올때 주인공 혼자 종으로 막 달리는 장면 와 진짜ㅋㅋㅋㅋ대박 무조건 아이맥스로 보세요온힘을 다해 뛸때 울컥한다 인생작 리스트에 하나 추가오랜만에 영화란 극장에서 보는 것이라는 느낌을 갖게 해 준 명작 카메라의 움직임 배우의 감정 360도로 전쟁이라는 공간 주인공에게 주어진 미션과 여정 그 모든 것이 완벽하게 짜여진 영화 정말 좋은 영화다원테이크 촬영신은 볼때마다 대단하다 후보에 오를만 했음스포일러가 포함된 감상평입니다 감상평 보기수많은 난관을 거치고 거쳐 도달한 곳은 결국 시작과 똑같은 풀밭 속 나무기둥 옆 전쟁은 여전히 계속되고 있지만 햇살이 그를 위로하듯이 드리운다영화가 보통  컷트 컷트로 찍는게 대부분인데ㅡ이영화는 한컷으로 촬영한거 같다ㅡ리얼 그장소에 내가 있는거 처럼 느껴졋고 끝까지 긴장감을 늦출 수 없다일단극장에서 보는걸  추천드립니다카메라감독 상 줘야 할판  엄청나게  잘 찍음솔직히 샘 멘데스 감독 좀 억울할듯기생충도 재밌게 봤지만 이거 보고나서 좀 억울했겠다는 생각이 팍듬상 많이 받았다길래 기대하고 본 영화인데 진짜 최고지루하지않고 끝까지 시간가는줄 모르고 본영화음악땜에 더 긴장하고 조마조마했음동료를 잃고 목숨을 잃을 위기를 극복해나가며 달려 얻은 것은 전쟁의 무의미함과 허무함 뿐이 모든 것이 하루만의 일이라니기생충이 그냥 백인이 나온 헐리우드 영화였다면 절대 1917을 이기지 못했을것 1917은 오히려 백인의 헐리우드 영화라 차별받음 진짜 근래 보기 드믄 명작전쟁이 끝나는 길은 마지막 한사람까지 죽는 것이다전쟁영화의 마스터피스 모든 것이 완벽한 영화스포일러가 포함된 감상평입니다 감상평 보기야외에서 롱테이크 방식으로 찍는게 쉬운게 아닌데 그걸 해낸 엄청난 영화이고 주인공들의 감정을 잘 드러냄 특히 마지막에 돌진하는 군인들과 다른 방향으로 뛰는 주인공의 모습은 굉장히 인상적임전쟁씬 안나온다고 보지말라던 사람들 너무 한심하다진짜 스크린에서 눈을 뗄 수가 없다 미친 몰입감에다가 전쟁터에서 있는거처럼 몸에 힘 빡 주고 보게 됨 그리고 갑자기 끝에 눈물이 흘렀다 예상하지 못한 감동이 울컥 올라와서 더 놀라운 영화병사를 따라가다보면 경험할 전쟁의 참상과 자연스레 따라오는 두려움과 먹먹함 이건 판타지를 제외한 영화의 기술이 구현할 수 있는 가장 최상의 리얼리티독일군보다 무서운건 NG다지금까지 이런 영화촬영기술은 본적이 없다 롱테이크 원샷으로 무려 1시간이다 배우는 배우대로 혼신의 힘을 다했고 촬영감독은 자신의 역량을 뛰어넘었다 무엇보다 이걸 연출한 감독의 역량은 미쳤다진짜 촬영 대박임 옆에서 같이 달리는 기분드는 건 당연이고 어느 한 부분에서는 배그처럼 진짜 내가 옆에있는 기분마저 듬 스토리는 단순해도 시간 가는 줄 몰랐던 강렬함 최고였다궁금해서 집근처에서 2D로 봤는데 보자마자 이건 아맥각이라는 생각이 들어서 주말에 아맥으로 또 볼 예정마지막에 눈물 날뻔함스포일러가 포함된 감상평입니다 감상평 보기전달을 해야하기에 다른 병사들과 다른 방향으로 미친듯이 뛰어가는 장면에서 왜인지 눈물이 났다1917년 4월6일 서부전선에 두시간동안 있다가 왔다와 울컥했다 봉준호가 어떻게 이영화를 이겼는지 모르겠다극장에 들어서는 순간 전장에 뛰어든 것이었다이건 영화관에서 안 보면 진짜 후회하는 영화전쟁의 참상을 온전히 객관적으로 바라본다는 것진짜 근래 본 영화중 최고다전쟁의 비극을 절제미를 지켜가며 담아낸 수작많은 사람이 봤으면 하는데 코로나 때문에 ㅠ이런영화를 만들어주는 것에 감사하다1917은 조용하게 강렬하다남자주인공이 왜 오스카 노미 안됐는지 의문인 영화압도적인 촬영기법과 그에못지않은 연기력 마지막 참호밖으로 뛰는 장면은 넋을 놓게 만든다기생충이 이거보다 대단한거였나5G로 내가 전쟁속에서 함께 나아가는 갓같은 착각에 빠진다 제국주의 속 장기판의 땅따먹기 졸이 되버린 청춘들이 1000만 이상 죽었다는 것을 잊지말자OO 한번 더본다 존나재밌다스포일러가 포함된 감상평입니다 감상평 보기와 마지막부분  전투 돌격 할때 주인공은 옆으로 뛰어가는 장면 소름각본이 중요한가 라는 의문을 던져준다정말 어떻게 촬영한거지 원테이크의 진수다1차 세계대전을 참여 할수 있습니다영국아카데미에서 1917이 작품상과 감독상을 모두 석권해 미국 아카데미 수상 예측을 실패하게 만든 건 영국배우들이 다수 출연한 영국영화였기 때문에 안방에서 상 몰아주기가 아니었을까 하는 게 오늘 조조로 보고 나서 느전쟁은 영화가 아닌것을 보여준 영화촬영 걍 미쳤음 경이로울 정도ㅠㅠ 마스터피스 ㅇㅈ정말 최고의 영화였다 진짜 영화보면서 경이롭기는 인셉션 이후로 처음이다철조망에 널부러진 시체구더기와 쥐가 들끓는 참호내가 만약 저기 있었다면 며칠만에 정신병에 걸리지 않았을까이 영화를 보면 기생충이 왜 아카데미 작품상을 탔는지 이해가 안 될 것이다이 영화는 마치 원테이크처럼 보이지만 실제론 원 컨티뉴어스 컷이라고 여러 장면을 마치 하나의 장면처럼 보이게 이어 붙여 만들었다고 합니다 그렇다고 해서 이 방법이 결코 쉬운 건 아닌데요 영화를 보는 내내 원테이크주인공에게 정우가 오버랩되긴했지만 몰입도와 긴장감 스토리 촬영기법 스토리 어떻게 러닝타임이 흘러간줄 모르겠습니다 군대 다녀오셨다면 남성분들께서는 더 재밌게 보실수 있겠네요나까지 셋이서 편지 전달하러 가는 기분이었음전쟁터에서 벗어날수 없는 느낌이 들었다너무 무섭고 답답했다화끈한 대규모 전투씬은 없다 오직 영국군이 대규모 진격하는 장면으로 끝이다 1차 세계대전의 처음이자 끝인 참호전도 없다그런데 이 영화 전쟁영화인데 스릴러마냥 긴박하게 흐른다영국판 태극기영화를 본게아니라 2시간 동안 1917년 4월 6일에 잇다 왔다작품상은 이건데오히려 단순한 스토리에 억지로 짜네는 스토리가 없어 좋았다영화보며 내가 그시대에 있다면 철조망에걸려 썩어가는 시체중 한명이 아닐까전쟁은 수퍼맨이 아닌 평범한 우리들이 그곳에 있었다아이맥스로 볼걸 후회된다Am I dying Yes아무리 롱테이크라도 이건 말이 안된다 아침부터 턱빠질뻔했다 영화계 종사자는 이거보면 머리 터질듯이 영화의 최대 단점  코로나중에 한국에 개봉한 것 많은 한국인이 이 마스터피스를 영화관에서 볼 수없다는 사실이 슬프다 목숨걸고 보러갈만 하다개봉전부터 촬영기법에 대해서 홍보하길래 기대많이 했는데 기대이상이라 더 놀라웠어요영화에 대한 몰입도가 정말 장난아닙니다영화자체는 호불호가 갈릴수도있다는 생각이들긴하지만 저는 정말 좋은작품 하나 봤다고 생각합니다1917 공감  덩케르크 비공감1917이 재미 있으면 추천 기생충이 재미 있으면 비추천총성과 포성 없는 전쟁터는 두려움과 공허함으로 가득채워져 있었다롱테이크 기법으로 촬영하여 단 1번 빼고 화면이 쭉 이어지 ...

# %% [markdown]
# ### 3. 토크나이징

# %%
# 토크나이징
twitter = Okt()  #twitter class 객체당!
komoran = Komoran()
kkma = Kkma()

# %%
def make_corpus(text):
    corpus = []
    for s in text.split('\n'):
        corpus.append(['/'.join(p) for p in twitter.pos(s)])
    return corpus

def make_corpus_rm_stopwords(text):
    corpus = []
    for s in text.split('\n'):
        corpus.append(['/'.join(p) for p in twitter.pos(s) if p[1] != "Josa"]) #임베딩에 필요없는 조사 빼고! 
    return corpus

# %%
# 토큰 모음집 만들기
corpus = make_corpus(ment)

#특수문자 제거
corpus = make_corpus_rm_stopwords(ment)

# %%
corpus
# Out:
# [['이/Noun',
#   '영화/Noun',
#   '미쳤다/Adjective',
#   '넷플릭스/Noun',
#   '일상/Noun',
#   '화/Suffix',
#   '된/Verb',
#   '시대/Noun',
#   '극장/Noun',
#   '존재/Noun',
#   '해야하는/Verb',
#   '이유/Noun',
#   '증명/Noun',
#   '해준다/Verb',
#   '충무로/Noun',
#   '이/Determiner',
#   '거/Noun',
#   '어케/Noun',
#   '하는거냐/Verb',
#   '아카데미/Noun',
#   '촬영상/Noun',
#   '음향효과/Noun',
#   '상/Suffix',
#   '시/Modifier',
#   '각/Modifier',
#   '효과/Noun',
#   '상/Suffix',
#   '받은/Verb',
#   '이유/Noun',
#   '고스/Noun',
#   '란/Noun',
#   '히/Adverb',
#   '녹아있는/Verb',
#   '영화/Noun',
#   'IMAX/Alpha',
#   '로/Noun',
#   '관람/Noun',
#   '하/Suffix',
#   '는걸/Noun',
#   '추천/Noun',
#   '한다/Verb',
#   '처절한/Adjective',
#   '전쟁/Noun',
#   '속/Noun',
#   '한/Verb',
#   '남자/Noun',
#   '영웅/Noun',
#   '만든/Verb',
#   '것/Noun',
#   '훈장/Noun',
#   '장군/Noun',
#   '명령/Noun',
#   '아닌/Adjective',
#   '바로/Noun',
#   '옆/Noun',
#   '전우/Noun',
#   '였다/Verb',
#   '촬영감독/Noun',
#   '영혼/Noun',
#   '갈아/Adverb',
#   '넣은/Verb',
#   '마스터피스/Noun',
#   '오스카/Noun',
#   '작품/Noun',
#   '상/Suffix',
#   '탔어도/Verb',
#   '할말/Verb',
#   '없었을것/Adjective',
#   '같다/Adjective',
#   '주인공/Noun',
#   '카메라/Noun',
#   '계속/Noun',
#   '따라가는데/Verb',
#   '세트/Noun',
#   '장이/Suffix',
#   '엄청/Adverb',
#   '넓은거에/Adjective',
#   '놀랐습니다/Verb',
#   '직접/Noun',
#   '1/Number',
#   '차/Noun',
#   '대전/Noun',
#   '참전/Noun',
#   '하는/Verb',
#   '느낌/Noun',
#   '이/Determiner',
#   '때/Noun',
#   '당시/Noun',
#   '군/Noun',
#   '20년/Number',
#   '뒤/Foreign',
#   '히틀러/Noun',
#   '극악/Noun',
#   '악마/Noun',
#   '자식/Noun',
#   '들/Suffix',
#   '다/Adverb',
#   '전장/Noun',
#   '몰리/Noun',
#   '더/Noun',
#   '최악/Noun',
#   '고통/Noun',
#   '받을껀데/Noun',
#   '참/Verb',
#   '관객/Noun',
#   '1917년/Number',
#   '4월/Number',
#   '6일/Number',
#   '로/Foreign',
#   '데려놓는/Verb',
#   '마법/Noun',
#   '같은/Adjective',
#   '작품/Noun',
#   '닥터스/Noun',
#   '트레인/Noun',
#   '의/Noun',
#   '판단력/Noun',
#   '좋았다/Adjective',
#   '아카데미/Noun',
#   '작품/Noun',
#   '상/Suffix',
#   '작품/Noun',
#   '전체/Noun',
#   '보는거니/Verb',
#   '기생충/Noun',
#   '받을수도/Verb',
#   '있다고/Adjective',
#   '보는데/Verb',
#   '감독/Noun',
#   '상/Suffix',
#   '1917/Number',
#   '줬어도/Verb',
#   '할말/Verb',
#   '없음/Adjective',
#   '감독/Noun',
#   '참신/Noun',
#   '성/Suffix',
#   '빛/Noun',
#   '발함/Noun',
#   '결론/Noun',
#   '적/Suffix',
#   '아카데미/Noun',
#   '작품/Noun',
#   '상과/Noun',
#   '감독/Noun',
#   '상/Suffix',
#   '1917/Number',
#   '이/Noun',
#   '받았어도/Verb',
#   '아무/Noun',
#   '할말/Verb',
#   '없는/Adjective',
#   '것/Noun',
#   '이/Determiner',
#   '앞/Noun',
#   '유사한/Adjective',
#   '영화/Noun',
#   '나올/Verb',
#   '때/Noun',
#   '회/Noun',
#   '자/Suffix',
#   '될/Verb',
#   '작품/Noun',
#   '특히/Adverb',
#   '원/Modifier',
#   '테이크/Noun',
#   '보이/Noun',
#   '하는/Verb',
#   '촬영/Noun',
#   '연출/Noun',
#   '봐도/Verb',
#   '봐도/Verb',
#   '놀랍다/Verb',
#   '솔직히/Adjective',
#   '연출/Noun',
#   '력/Suffix',
#   '최고/Noun',
#   '영화/Noun',
#   '마치/Noun',
#   '우리/Noun',
#   '투명인간/Noun',
#   '되서/Verb',
#   '그/Noun',
#   '들/Suffix',
#   '지켜보는/Verb',
#   '듯/Noun',
#   '했다/Verb',
#   '마지막/Noun',
#   '장면/Noun',
#   '영화/Noun',
#   '내내/Noun',
#   '쉴/Verb',
#   '시간/Noun',
#   '없었던것에/Adjective',
#   '대한/Noun',
#   '피로/Noun',
#   '감/Noun',
#   '풀어줘서/Verb',
#   '기승/Noun',
#   '전결/Noun',
#   '완벽/Noun',
#   '스포일러/Noun',
#   '포함/Noun',
#   '된/Verb',
#   '감상/Noun',
#   '평/Noun',
#   '입니다/Adjective',
#   '감상/Noun',
#   '평/Noun',
#   '보기/Noun',
#   '노래/Noun',
#   '쳐/Verb',
#   '안/VerbPrefix',
#   '듣고/Verb',
#   '뛰어갔으면/Verb',
#   '80/Number',
#   '명/Noun',
#   '더/Noun',
#   '살렸겠다/Verb',
#   '솔직히/Adjective',
#   '나/Noun',
#   '기생충/Noun',
#   '이영화/Noun',
#   '더/Noun',
#   '재미있었다/Adjective',
#   '진짜/Noun',
#   '원/Modifier',
#   '테이크/Noun',
#   '장면/Noun',
#   '너무/Adverb',
#   '긴거/Verb',
#   '아님/Adjective',
#   '촬영/Noun',
#   '하기/Verb',
#   '진짜/Noun',
#   '힘들었을/Adjective',
#   '듯/Noun',
#   '막판/Noun',
#   '횡/Noun',
#   '수많은/Adjective',
#   '병사/Noun',
#   '신호/Noun',
#   '함께/Adverb',
#   '우르르/Noun',
#   '튀어나올/Verb',
#   '때/Noun',
#   '주인공/Noun',
#   '혼자/Noun',
#   '종/Noun',
#   '막/Noun',
#   '달리는/Verb',
#   '장면/Noun',
#   '와/Verb',
#   '진짜/Noun',
#   'ㅋㅋㅋㅋ/KoreanParticle',
#   '대박/Noun',
#   '무조건/Noun',
#   '아이맥스/Noun',
#   '보세요/Verb',
#   '온/Modifier',
#   '힘/Noun',
#   '다해/Noun',
#   '뛸/Verb',
#   '때/Noun',
#   '울컥/Adverb',
#   '한다/Verb',
#   '인생/Noun',
#   '작/Noun',
#   '리스트/Noun',
#   '하나/Noun',
#   '추가/Noun',
#   '오랜/Modifier',
#   '만/Noun',
#   '영/Modifier',
#   '화란/Noun',
#   '극장/Noun',
#   '보는/Verb',
#   '것/Noun',
#   '느낌/Noun',
#   '갖게/Verb',
#   '해/Noun',
#   '준/Noun',
#   '명작/Noun',
#   '카메라/Noun',
#   '움직임/Noun',
#   '배우/Noun',
#   '감정/Noun',
#   '360/Number',
#   '도로/Noun',
#   '전쟁/Noun',
#   '공간/Noun',
#   '주인공/Noun',
#   '주어진/Verb',
#   '미션/Noun',
#   '여정/Noun',
#   '그/Noun',
#   '모든/Noun',
#   '것/Noun',
#   '완벽하게/Adjective',
#   '짜여진/Verb',
#   '영화/Noun',
#   '정말/Noun',
#   '좋은/Adjective',
#   '영화/Noun',
#   '원/Modifier',
#   '테이크/Noun',
#   '촬영/Noun',
#   '신은/Verb',
#   '볼때/Noun',
#   '대단하다/Adjective',
#   '후보/Noun',
#   '오를만/Verb',
#   '했음/Verb',
#   '스포일러/Noun',
#   '포함/Noun',
#   '된/Verb',
#   '감상/Noun',
#   '평/Noun',
#   '입니다/Adjective',
#   '감상/Noun',
#   '평/Noun',
#   '보기/Noun',
#   '수많은/Adjective',
#   '난관/Noun',
#   '거치/Noun',
#   '거쳐/Verb',
#   '도달/Noun',
#   '곳/Noun',
#   '결국/Adverb',
#   '시작/Noun',
#   '똑같은/Adjective',
#   '풀밭/Noun',
#   '속/Noun',
#   '나무/Noun',
#   '기둥/Noun',
#   '옆/Noun',
#   '전쟁/Noun',
#   '여전히/Adjective',
#   '계속/Noun',
#   '되고/Verb',
#   '있지만/Adjective',
#   '햇살/Noun',
#   '그/Noun',
#   '위로/Noun',
#   '하/Suffix',
#   '듯이/Noun',
#   '드리운다/Verb',
#   '영화/Noun',
#   '보통/Noun',
#   '컷트/Noun',
#   '컷트/Noun',
#   '찍는게/Verb',
#   '대부분/Noun',
#   'ㅡ/KoreanParticle',
#   '이영화/Noun',
#   '한/Determiner',
#   '컷/Noun',
#   '촬영/Noun',
#   '한/Determiner',
#   '거/Noun',
#   '같다/Adjective',
#   'ㅡ/KoreanParticle',
#   '리얼/Noun',
#   '그/Determiner',
#   '장소/Noun',
#   '내/Noun',
#   '있는거/Adjective',
#   '처럼/Noun',
#   '느껴졋/Noun',
#   '끝/Noun',
#   '긴장감/Noun',
#   '늦출/Verb',
#   '수/Noun',
#   '없다/Adjective',
#   '일단/Noun',
#   '극장/Noun',
#   '보는걸/Verb',
#   '추천/Noun',
#   '드립니다/Verb',
#   '카메라감독/Noun',
#   '상/Noun',
#   '줘야/Verb',
#   '할/Verb',
#   '판/Noun',
#   '엄청나게/Adjective',
#   '잘/Verb',
#   '찍음/Verb',
#   '솔직히/Adjective',
#   '샘/Noun',
#   '멘/Verb',
#   '데스/Noun',
#   '감독/Noun',
#   '좀/Noun',
#   '억울할듯/Adjective',
#   '기생충/Noun',
#   '재밌게/Adjective',
#   '봤지만/Verb',
#   '이/Determiner',
#   '거/Noun',
#   '보고나서/Verb',
#   '좀/Noun',
#   '억울했겠다는/Adjective',
#   '생각/Noun',
#   '팍듬상/Noun',
#   '많이/Adverb',
#   '받았다길래/Verb',
#   '기대하고/Adjective',
#   '본/Verb',
#   '영화/Noun',
#   '진짜/Noun',
#   '최고/Noun',
#   '지루하지/Adjective',
#   '않고/Verb',
#   '끝/Noun',
#   '시간/Noun',
#   '가는줄/Verb',
#   '모르고/Verb',
#   '본/Modifier',
#   '영화음악/Noun',
#   '땜/Noun',
#   '더/Noun',
#   '긴장/Noun',
#   '조마조마했음/Adjective',
#   '동료/Noun',
#   '잃고/Verb',
#   '목숨/Noun',
#   '잃을/Verb',
#   '위기/Noun',
#   '극복/Noun',
#   '해/Verb',
#   '나가며/Verb',
#   '달려/Verb',
#   '얻은/Verb',
#   '것/Noun',
#   '전쟁/Noun',
#   '무의미함과/Adjective',
#   '허무함/Adjective',
#   '뿐이/Adjective',
#   '모든/Noun',
#   '것/Noun',
#   '하루/Noun',
#   '일이/Noun',
#   '기생충/Noun',
#   '그냥/Noun',
#   '백인/Noun',
#   '나온/Verb',
#   '헐리우드/Noun',
#   '영화/Noun',
#   '였다면/Verb',
#   '절대/Noun',
#   '1917/Number',
#   '이기/Noun',
#   '못/VerbPrefix',
#   '했을것/Verb',
#   '1917/Number',
#   '은/Noun',
#   '오히려/Noun',
#   '백인/Noun',
#   '헐리우드/Noun',
#   '영화/Noun',
#   '차별/Noun',
#   '받음/Verb',
#   '진짜/Noun',
#   '근래/Noun',
#   '보기/Noun',
#   '드믄/Noun',
#   '명작/Noun',
#   '전쟁/Noun',
#   '끝나는/Verb',
#   '길은/Adjective',
#   '마지막/Noun',
#   '한/Determiner',
#   '사람/Noun',
#   '죽는/Verb',
#   '것/Noun',
#   '전쟁영화/Noun',
#   '마스터피스/Noun',
#   '모든/Noun',
#   '것/Noun',
#   '완벽한/Adjective',
#   '영화/Noun',
#   '스포일러/Noun',
#   '포함/Noun',
#   '된/Verb',
#   '감상/Noun',
#   '평/Noun',
#   '입니다/Adjective',
#   '감상/Noun',
#   '평/Noun',
#   '보기/Noun',
#   '야외/Noun',
#   '롱/Noun',
#   '테이크/Noun',
#   '방식/Noun',
#   '찍는게/Verb',
#   '쉬운게/Adjective',
#   '아닌데/Adjective',
#   '그걸/Adverb',
#   '해낸/Verb',
#   '엄청난/Adjective',
#   '영화/Noun',
#   '주인공/Noun',
#   '들/Suffix',
#   '감정/Noun',
#   '잘/Verb',
#   '드러냄/Verb',
#   '특히/Adverb',
#   '마지막/Noun',
#   '돌진/Noun',
#   '하는/Verb',
#   '군인/Noun',
#   '들/Suffix',
#   '다른/Noun',
#   '방향/Noun',
#   '뛰는/Verb',
#   '주인공/Noun',
#   '모습/Noun',
#   '굉장히/Adjective',
#   '인상/Noun',
#   '적임/Noun',
#   '전쟁/Noun',
#   '씬/Noun',
#   '안/VerbPrefix',
#   '나온다고/Verb',
#   '보지/Noun',
#   '말라던/Adjective',
#   '사람/Noun',
#   '들/Suffix',
#   '너무/Adverb',
#   '한심하다/Adjective',
#   '진짜/Noun',
#   '스크린/Noun',
#   '눈/Noun',
#   '뗄/Verb',
#   '수가/Noun',
#   '없다/Adjective',
#   '미친/Adjective',
#   '몰입/Noun',
#   '감/Noun',
#   '전쟁/Noun',
#   '터/Noun',
#   '있는거처럼/Adjective',
#   '몸/Noun',
#   '힘/Noun',
#   '빡/Noun',
#   '주고/Verb',
#   '보게/Verb',
#   '됨/Verb',
#   '그리고/Conjunction',
#   '갑자기/Noun',
#   '끝/Noun',
#   '눈물/Noun',
#   '흘렀다/Verb',
#   '예상/Noun',
#   '하지/Verb',
#   '못/Noun',
#   '감동/Noun',
#   '울컥/Adverb',
#   '올라와서/Verb',
#   '더/Noun',
#   '놀라운/Adjective',
#   '영화/Noun',
#   '병사/Noun',
#   '따라가다/Verb',
#   '보면/Verb',
#   '경험/Noun',
#   '할/Verb',
#   '전쟁/Noun',
#   '참상/Noun',
#   '자연스레/Adverb',
#   '따라오는/Verb',
#   '두려움/Noun',
#   '먹/Verb',
#   '먹/Verb',
#   '함/Noun',
#   '이건/Noun',
#   '판타지/Noun',
#   '제외/Noun',
#   '영화/Noun',
#   '기술/Noun',
#   '구현/Noun',
#   '할/Verb',
#   '수/Noun',
#   '있는/Adjective',
#   '가장/Noun',
#   '최상/Noun',
#   '리얼리티/Noun',
#   '독일군/Noun',
#   '무서운건/Adjective',
#   'NG/Alpha',
#   '다지/Noun',
#   '금/Noun',
#   '이런/Adjective',
#   '영화/Noun',
#   '촬영/Noun',
#   '기술/Noun',
#   '본적/Noun',
#   '없다/Adjective',
#   '롱/Noun',
#   '테이크/Noun',
#   '원샷/Noun',
#   '무려/Noun',
#   '1시간/Number',
#   '이다/Foreign',
#   '배우는/Verb',
#   '배우/Noun',
#   '혼신/Noun',
#   '힘/Noun',
#   '다/Adverb',
#   '했고/Verb',
#   '촬영감독/Noun',
#   '자신/Noun',
#   '역량/Noun',
#   '뛰어넘었다/Verb',
#   '무엇/Noun',
#   '이/Determiner',
#   '걸/Noun',
#   '연출/Noun',
#   '감독/Noun',
#   '역량/Noun',
#   '미쳤다/Adjective',
#   '진짜/Noun',
#   '촬영/Noun',
#   '대박/Noun',
#   '임/Noun',
#   '옆/Noun',
#   '같이/Adverb',
#   '달리는/Verb',
#   '기분/Noun',
#   '드는/Verb',
#   '건/Noun',
#   '당/Modifier',
#   '연/Noun',
#   '어느/Adverb',
#   '한/Verb',
#   '부분/Noun',
#   '배/Noun',
#   '그/Determiner',
#   '처럼/Noun',
#   '진짜/Noun',
#   '내/Noun',
#   '옆/Noun',
#   '있는/Adjective',
#   '기분/Noun',
#   '듬/Noun',
#   '스토리/Noun',
#   '단순해도/Adjective',
#   '시간/Noun',
#   '가는/Verb',
#   '줄/Noun',
#   '몰랐던/Verb',
#   '강렬함/Adjective',
#   '최고/Noun',
#   '였다/Verb',
#   '궁금해서/Adjective',
#   '집/Noun',
#   '근처/Noun',
#   '2/Number',
#   'D/Alpha',
#   '로/Noun',
#   '봤는데/Verb',
#   '보자마자/Verb',
#   '이건/Noun',
#   '아/Exclamation',
#   '맥각/Noun',
#   '생각/Noun',
#   '들어서/Verb',
#   '주말/Noun',
#   '아/Exclamation',
#   '맥/Noun',
#   '또/Noun',
#   '볼/Noun',
#   '예정/Noun',
#   '마지막/Noun',
#   '눈물/Noun',
#   '날/Noun',
#   '뻔함/Adjective',
#   '스포일러/Noun',
#   '포함/Noun',
#   '된/Verb',
#   '감상/Noun',
#   '평/Noun',
#   '입니다/Adjective',
#   '감상/Noun',
#   '평/Noun',
#   '보기/Noun',
#   '전달/Noun',
#   '해야하기에/Verb',
#   '다른/Noun',
#   '병사/Noun',
#   '들/Suffix',
#   '다른/Noun',
#   '방향/Noun',
#   '미친듯이/Adjective',
#   '뛰어가는/Verb',
#   '장면/Noun',
#   '왜인/Noun',
#   '눈물/Noun',
#   '났다/Verb',
#   '1917년/Number',
#   '4월/Number',
#   '6일/Number',
#   '서/Modifier',
#   '부전선/Noun',
#   '두/Determiner',
#   '시간/Noun',
#   '동안/Noun',
#   '있다가/Adjective',
#   '왔다와/Verb',
#   '울컥/Adverb',
#   '했다/Verb',
#   '봉준호/Noun',
#   '어떻게/Adjective',
#   '이영화/Noun',
#   '이겼는지/Verb',
#   '모르겠다/Verb',
#   '극장/Noun',
#   '들어서는/Verb',
#   '순간/Noun',
#   '전장/Noun',
#   '뛰어든/Verb',
#   '것/Noun',
#   '이었다이건/Verb',
#   '영화관/Noun',
#   '안/Noun',
#   '보면/Verb',
#   '진짜/Noun',
#   '후회/Noun',
#   '하는/Verb',
#   '영화/Noun',
#   '전쟁/Noun',
#   '참상/Noun',
#   '온전히/Verb',
#   '객관/Noun',
#   '적/Suffix',
#   '바라본다는/Verb',
#   '것/Noun',
#   '진짜/Noun',
#   '근래/Noun',
#   '본/Verb',
#   '영화/Noun',
#   '중/Suffix',
#   '최고다/Noun',
#   '전쟁/Noun',
#   '비극/Noun',
#   '절제/Noun',
#   '미를/Adjective',
#   '지켜가며/Verb',
#   '담아/Verb',
#   '낸/Verb',
#   '수작/Noun',
#   '많은/Adjective',
#   '사람/Noun',
#   '봤으면/Verb',
#   '하는데/Verb',
#   '코로나/Noun',
#   '때문/Noun',
#   'ㅠ/KoreanParticle',
#   '이런/Modifier',
#   '영화/Noun',
#   '만들어주는/Verb',
#   '것/Noun',
#   '감사하다/Verb',
#   '1917/Number',
#   '은/Noun',
#   '조용하게/Adjective',
#   '강렬하다/Adjective',
#   '남자/Noun',
#   '주인공/Noun',
#   '왜/Noun',
#   '오스카/Noun',
#   '노미/Noun',
#   '안/VerbPrefix',
#   '됐는지/Verb',
#   '의문/Noun',
#   '영화/Noun',
#   '압도/Noun',
#   '적/Suffix',
#   '촬영/Noun',
#   '기법/Noun',
#   '그/Noun',
#   '못지않은/Adjective',
#   '연기력/Noun',
#   '마지막/Noun',
#   '참호/Noun',
#   '밖/Noun',
#   '뛰는/Verb',
#   '장면/Noun',
#   '넋/Noun',
#   '놓게/Verb',
#   '만든다/Verb',
#   '기생충/Noun',
#   '이/Determiner',
#   '거/Noun',
#   '대단한거였나/Adjective',
#   '5/Number',
#   'G/Alpha',
#   '로/Noun',
#   '내/Noun',
#   '전쟁/Noun',
#   '속/Noun',
#   '함께/Adverb',
#   '나아가는/Verb',
#   '갓/Noun',
#   '같은/Adjective',
#   '착각/Noun',
#   '빠진다/Verb',
#   '제국주의/Noun',
#   '속/Noun',
#   '장기판/Noun',
#   '땅/Noun',
#   '따먹기/Verb',
#   '졸이/Verb',
#   '되/Verb',
#   '버린/Verb',
#   '청춘/Noun',
#   '들/Suffix',
#   '1000만/Number',
#   '이상/Noun',
#   '죽었다는/Verb',
#   '것/Noun',
#   '잊지말자/Verb',
#   'OO/Alpha',
#   '한번/Noun',
#   '더/Noun',
#   '본다/Verb',
#   '존나/Noun',
#   '재밌다/Adjective',
#   '스포일러/Noun',
#   '포함/Noun',
#   '된/Verb',
#   '감상/Noun',
#   '평/Noun',
#   '입니다/Adjective',
#   '감상/Noun',
#   '평/Noun',
#   '보기/Noun',
#   '마지막/Noun',
#   '부분/Noun',
#   '전투/Noun',
#   '돌격/Noun',
#   '할/Verb',
#   '때/Noun',
#   '주인공/Noun',
#   '옆/Noun',
#   '뛰어가는/Verb',
#   '장면/Noun',
#   '소름/Noun',
#   '각본/Noun',
#   '중요한가/Adjective',
#   '의문/Noun',
#   '던져/Verb',
#   '준다/Verb',
#   '정말/Noun',
#   '어떻게/Adjective',
#   '촬영/Noun',
#   '한/Determiner',
#   '거지/Noun',
#   '원/Modifier',
#   '테이크/Noun',
#   '진수/Noun',
#   '1/Number',
#   '차/Noun',
#   '세계대전/Noun',
#   '참여/Noun',
#   '할수/Verb',
#   '있습니다/Adjective',
#   '영국/Noun',
#   '아카데미/Noun',
#   '1917/Number',
#   '이/Noun',
#   '작품/Noun',
#   '상과/Noun',
#   '감독/Noun',
#   '상/Suffix',
#   '모두/Noun',
#   '석권/Noun',
#   '해/Verb',
#   '미국/Noun',
#   '아카데미/Noun',
#   '수상/Noun',
#   '예측/Noun',
#   '실패하게/Adjective',
#   '만든/Verb',
#   '건/Noun',
#   '영국/Noun',
#   '배우/Noun',
#   '들/Suffix',
#   '다수/Noun',
#   '출연/Noun',
#   '영국영화/Noun',
#   '였기/Verb',
#   '때문/Noun',
#   '안방/Noun',
#   '상/Noun',
#   '몰아/Verb',
#   '주기/Noun',
#   '아니었을까/Adjective',
#   '하는/Verb',
#   '게/Noun',
#   '오늘/Noun',
#   '조조/Noun',
#   '보고/Noun',
#   '나서/Verb',
#   '느전쟁/Noun',
#   '영화/Noun',
#   '아닌것을/Adjective',
#   '보여준/Verb',
#   '영화/Noun',
#   '촬영/Noun',
#   '걍/Adverb',
#   '미쳤음/Adjective',
#   '경이/Noun',
#   '울/Noun',
#   '정도/Noun',
#   'ㅠㅠ/KoreanParticle',
#   '마스터피스/Noun',
#   'ㅇㅈ/KoreanParticle',
#   '정말/Noun',
#   '최고/Noun',
#   '영화/Noun',
#   '였다/Verb',
#   '진짜/Noun',
#   '영화/Noun',
#   '보면서/Verb',
#   '경/Noun',
#   '이롭/Adjective',
#   '기는/Verb',
#   '인셉션/Noun',
#   '이후/Noun',
#   '처음/Noun',
#   '철조망/Noun',
#   '널/Noun',
#   '부러진/Verb',
#   '시체/Noun',
#   '구더기/Noun',
#   '쥐/Noun',
#   '들끓는/Verb',
#   '참호/Noun',
#   '내/Noun',
#   '만약/Noun',
#   '저기/Noun',
#   '있었다면/Adjective',
#   '며칠/Noun',
#   '정신병/Noun',
#   '걸리지/Verb',
#   '않았을까/Verb',
#   '이/Determiner',
#   '영화/Noun',
#   '보면/Verb',
#   '기생충/Noun',
#   '왜/Noun',
#   '아카데미/Noun',
#   '작품/Noun',
#   '상/Suffix',
#   '탔는지/Verb',
#   '이해/Noun',
#   '안/Noun',
#   '될/Verb',
#   '것/Noun',
#   '이/Determiner',
#   '영화/Noun',
#   '마치/Noun',
#   '원/Modifier',
#   '테이크/Noun',
#   '보이/Noun',
#   '실제/Noun',
#   '론/Noun',
#   '원/Noun',
#   '컨티뉴/Noun',
#   '어스/Noun',
#   '컷/Noun',
#   '여러/Noun',
#   '장면/Noun',
#   '마치/Noun',
#   '하나/Noun',
#   '장면/Noun',
#   '보이/Noun',
#   '이어/Verb',
#   '붙여/Verb',
#   '만들었다고/Verb',
#   '합니다/Verb',
#   '그렇다고/Conjunction',
#   '해서/Verb',
#   '이/Noun',
#   '방법/Noun',
#   '결코/Noun',
#   '쉬운/Adjective',
#   '건/Noun',
#   '아닌데요/Adjective',
#   '영화/Noun',
#   '보는/Verb',
#   '내내/Noun',
#   '원/Modifier',
#   '테이크/Noun',
#   '주인공/Noun',
#   '정우/Noun',
#   '오버/Noun',
#   '랩/Noun',
#   '되긴/Verb',
#   ...]]

# %% [markdown]
# ### 4. 임베딩

# %%
#임베딩
from gensim.models import Word2Vec, fasttext

#임베딩(w2v_skipgram)모델 생성
# size : 벡터의 수
# min count : 출현 빈도
# sg : 0 -> CBOW, 1 -> Skip-Gram


# Skip_Gram 모델 생성
Skip_Gram_model = Word2Vec(corpus, size=15, window=3, min_count=3, workers=1, iter=1000, sg=1)


# CBOW 모델 생성 
CBOW = Word2Vec(corpus, size=15, window=3, min_count=3, workers=3, iter=1000, sg=0)

# %%
#index2word
words = Skip_Gram_model.wv.index2word #one-hot encoding알아서 해줌 
words
# Out:
# ['영화/Noun',
#  '상/Suffix',
#  '전쟁/Noun',
#  '작품/Noun',
#  '촬영/Noun',
#  '것/Noun',
#  '들/Suffix',
#  '감상/Noun',
#  '평/Noun',
#  '1917/Number',
#  '테이크/Noun',
#  '이/Determiner',
#  '이/Noun',
#  '아카데미/Noun',
#  '기생충/Noun',
#  '감독/Noun',
#  '진짜/Noun',
#  '된/Verb',
#  '연출/Noun',
#  '장면/Noun',
#  '거/Noun',
#  '주인공/Noun',
#  '하는/Verb',
#  '더/Noun',
#  '보기/Noun',
#  '원/Modifier',
#  '마지막/Noun',
#  '스포일러/Noun',
#  '포함/Noun',
#  '입니다/Adjective',
#  '스토리/Noun',
#  '속/Noun',
#  '최고/Noun',
#  '정말/Noun',
#  '끝/Noun',
#  '생각/Noun',
#  '롱/Noun',
#  '극장/Noun',
#  '이유/Noun',
#  '옆/Noun',
#  '카메라/Noun',
#  '때/Noun',
#  '시간/Noun',
#  '한/Determiner',
#  '내/Noun',
#  '없다/Adjective',
#  '할/Verb',
#  '보면/Verb',
#  '기법/Noun',
#  '로/Noun',
#  '였다/Verb',
#  '마스터피스/Noun',
#  '1/Number',
#  '없는/Adjective',
#  '그/Noun',
#  '안/VerbPrefix',
#  '이영화/Noun',
#  '너무/Adverb',
#  '힘/Noun',
#  '하나/Noun',
#  '보는/Verb',
#  '모든/Noun',
#  '그/Determiner',
#  '수/Noun',
#  '사람/Noun',
#  '이건/Noun',
#  '어떻게/Adjective',
#  '촬영상/Noun',
#  '추천/Noun',
#  '한다/Verb',
#  '오스카/Noun',
#  '할말/Verb',
#  '차/Noun',
#  '느낌/Noun',
#  '다/Adverb',
#  '전장/Noun',
#  '1917년/Number',
#  '4월/Number',
#  '6일/Number',
#  '적/Suffix',
#  '보이/Noun',
#  '봐도/Verb',
#  '솔직히/Adjective',
#  '마치/Noun',
#  '했다/Verb',
#  '내내/Noun',
#  '감/Noun',
#  '수많은/Adjective',
#  '병사/Noun',
#  '아이맥스/Noun',
#  '울컥/Adverb',
#  '영/Modifier',
#  '배우/Noun',
#  '상/Noun',
#  '잘/Verb',
#  '못/VerbPrefix',
#  '은/Noun',
#  '다른/Noun',
#  '몰입/Noun',
#  '터/Noun',
#  '그리고/Conjunction',
#  '눈물/Noun',
#  '기분/Noun',
#  '건/Noun',
#  '동안/Noun',
#  '중/Suffix',
#  '코로나/Noun',
#  '왜/Noun',
#  '처음/Noun',
#  '개봉/Noun']

# %%
#index2word
words_c = CBOW.wv.index2word #one-hot encoding알아서 해줌 
words_c
# Out:
# ['영화/Noun',
#  '상/Suffix',
#  '전쟁/Noun',
#  '작품/Noun',
#  '촬영/Noun',
#  '것/Noun',
#  '들/Suffix',
#  '감상/Noun',
#  '평/Noun',
#  '1917/Number',
#  '테이크/Noun',
#  '이/Determiner',
#  '이/Noun',
#  '아카데미/Noun',
#  '기생충/Noun',
#  '감독/Noun',
#  '진짜/Noun',
#  '된/Verb',
#  '연출/Noun',
#  '장면/Noun',
#  '거/Noun',
#  '주인공/Noun',
#  '하는/Verb',
#  '더/Noun',
#  '보기/Noun',
#  '원/Modifier',
#  '마지막/Noun',
#  '스포일러/Noun',
#  '포함/Noun',
#  '입니다/Adjective',
#  '스토리/Noun',
#  '속/Noun',
#  '최고/Noun',
#  '정말/Noun',
#  '끝/Noun',
#  '생각/Noun',
#  '롱/Noun',
#  '극장/Noun',
#  '이유/Noun',
#  '옆/Noun',
#  '카메라/Noun',
#  '때/Noun',
#  '시간/Noun',
#  '한/Determiner',
#  '내/Noun',
#  '없다/Adjective',
#  '할/Verb',
#  '보면/Verb',
#  '기법/Noun',
#  '로/Noun',
#  '였다/Verb',
#  '마스터피스/Noun',
#  '1/Number',
#  '없는/Adjective',
#  '그/Noun',
#  '안/VerbPrefix',
#  '이영화/Noun',
#  '너무/Adverb',
#  '힘/Noun',
#  '하나/Noun',
#  '보는/Verb',
#  '모든/Noun',
#  '그/Determiner',
#  '수/Noun',
#  '사람/Noun',
#  '이건/Noun',
#  '어떻게/Adjective',
#  '촬영상/Noun',
#  '추천/Noun',
#  '한다/Verb',
#  '오스카/Noun',
#  '할말/Verb',
#  '차/Noun',
#  '느낌/Noun',
#  '다/Adverb',
#  '전장/Noun',
#  '1917년/Number',
#  '4월/Number',
#  '6일/Number',
#  '적/Suffix',
#  '보이/Noun',
#  '봐도/Verb',
#  '솔직히/Adjective',
#  '마치/Noun',
#  '했다/Verb',
#  '내내/Noun',
#  '감/Noun',
#  '수많은/Adjective',
#  '병사/Noun',
#  '아이맥스/Noun',
#  '울컥/Adverb',
#  '영/Modifier',
#  '배우/Noun',
#  '상/Noun',
#  '잘/Verb',
#  '못/VerbPrefix',
#  '은/Noun',
#  '다른/Noun',
#  '몰입/Noun',
#  '터/Noun',
#  '그리고/Conjunction',
#  '눈물/Noun',
#  '기분/Noun',
#  '건/Noun',
#  '동안/Noun',
#  '중/Suffix',
#  '코로나/Noun',
#  '왜/Noun',
#  '처음/Noun',
#  '개봉/Noun']

# %%
# text 토큰 임베딩 벡터
vectors = Skip_Gram_model.wv.vectors
vectors
# Out:
# array([[-0.01328132,  0.29977754, -0.12890866, ..., -0.12989846,
#          0.68839484,  0.57805777],
#        [-0.06669123,  0.6910944 ,  0.30329973, ..., -0.6767964 ,
#          0.8342213 ,  0.42774403],
#        [-0.47695935,  0.40586737,  0.17948739, ...,  0.20457968,
#          0.4669204 ,  0.83351165],
#        ...,
#        [-0.19757845,  0.43172327,  0.50861937, ..., -1.3834512 ,
#          0.39324275,  1.3246176 ],
#        [ 0.72976035,  0.18452746, -0.78180337, ...,  0.11930243,
#         -0.21970889,  0.8076524 ],
#        [-1.6298087 ,  0.08539601, -0.3485778 , ...,  0.6286506 ,
#          0.4777508 ,  2.1731274 ]], dtype=float32)

# %%
# text 토큰 임베딩 벡터
vectors_c =CBOW.wv.vectors
vectors_c
# Out:
# array([[ 0.10305395,  0.6904124 , -0.02980778, ..., -0.2095866 ,
#          0.08410493,  0.10246874],
#        [-0.27011952,  1.4804407 ,  0.94493717, ..., -1.2455472 ,
#          0.66321766, -0.29941386],
#        [-1.0752478 ,  0.3617127 ,  1.2178569 , ..., -0.14788759,
#          0.4256794 ,  1.0379702 ],
#        ...,
#        [ 0.915051  ,  1.1727942 ,  2.1676443 , ..., -3.4047635 ,
#         -0.9263494 ,  1.0527451 ],
#        [ 2.064485  , -0.25829726, -2.5788903 , ...,  0.23212297,
#         -0.38682917,  1.0665897 ],
#        [-2.6351814 , -1.1313297 , -2.017846  , ...,  1.140657  ,
#          2.995204  ,  3.513869  ]], dtype=float32)

# %%
# 토큰과 벡터 zip
Skip_Gram_model_result = dict(zip(words, vectors))
CBOW_model_result = dict(zip(words_c, vectors_c))

# %%
# 유사도 top5
# 두 벡터 사이의 코사인 유사도를 구해줍니다
print(Skip_Gram_model.most_similar('주인공/Noun', topn=5)) #유사한 top5개 보기  #word2vec 코사인 유사도! 

print(Skip_Gram_model.most_similar('테이크/Noun', topn=5))

print(Skip_Gram_model.most_similar('1917/Number', topn=5))

print(Skip_Gram_model.most_similar('전쟁/Noun', topn=5))
# Out:
# [('테이크/Noun', 0.7469764947891235), ('원/Modifier', 0.6964125633239746), ('그/Noun', 0.6354554295539856), ('안/VerbPrefix', 0.6130884289741516), ('때/Noun', 0.6105833053588867)]
# [('원/Modifier', 0.8605194687843323), ('롱/Noun', 0.7956092953681946), ('촬영/Noun', 0.7708734273910522), ('주인공/Noun', 0.7469764947891235), ('그/Noun', 0.6424469351768494)]
# [('작품/Noun', 0.8347244262695312), ('상/Suffix', 0.816941499710083), ('기생충/Noun', 0.7609391212463379), ('감독/Noun', 0.736426830291748), ('이/Noun', 0.7320429086685181)]
# [('진짜/Noun', 0.7718602418899536), ('것/Noun', 0.7170963883399963), ('사람/Noun', 0.6892199516296387), ('속/Noun', 0.6761137247085571), ('더/Noun', 0.6212199926376343)]
# C:\Users\MiSung\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\MiSung\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """
# C:\Users\MiSung\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   import sys
# C:\Users\MiSung\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':

# %%
print(CBOW.most_similar('주인공/Noun', topn=5))  #유사한 top5개 보기  #word2vec 코사인 유사도! 

print(CBOW.most_similar('테이크/Noun', topn=5))

print(CBOW.most_similar('1917/Number', topn=5))

print(CBOW.most_similar('전쟁/Noun', topn=5))
# Out:
# [('테이크/Noun', 0.6144874095916748), ('원/Modifier', 0.5484306812286377), ('때/Noun', 0.504020631313324), ('병사/Noun', 0.4858534336090088), ('어떻게/Adjective', 0.47481995820999146)]
# [('롱/Noun', 0.7648367285728455), ('원/Modifier', 0.7202802300453186), ('기법/Noun', 0.6528427004814148), ('주인공/Noun', 0.6144874095916748), ('촬영/Noun', 0.5988196134567261)]
# [('작품/Noun', 0.7876625061035156), ('상/Suffix', 0.7572681903839111), ('못/VerbPrefix', 0.7009114027023315), ('감독/Noun', 0.6701452732086182), ('할말/Verb', 0.6619683504104614)]
# [('사람/Noun', 0.5671355724334717), ('속/Noun', 0.5650290846824646), ('것/Noun', 0.5514854192733765), ('진짜/Noun', 0.5305742621421814), ('너무/Adverb', 0.5286405086517334)]
# C:\Users\MiSung\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# C:\Users\MiSung\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\MiSung\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """
# C:\Users\MiSung\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   import sys

# %% [markdown]
# #### 순위는 다르지만, 유사하다고 나오는 단어는 비슷하다.!

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
 
# tsne로 만들어서 plot하는 코드.. 이건 구글링해서 출처 표시!
# tsne로 만든 이유는 단어의 관계를 보기에 가장 적합한 것이라고 생각했기 때문.
def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []
 
    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)
    plt.rc('font', family='Malgun Gothic')
 
    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()
    #https://www.kaggle.com/jeffd23/visualizing-word-vectors-with-t-sne

# %%
tsne_plot(Skip_Gram_model)
# Out:
# C:\Users\MiSung\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if sys.path[0] == '':
# C:\Users\MiSung\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\MiSung\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 인사이트 도출하기!

# %% [markdown]
# 1. 눈에 띄는 군집을 보면, ![image](https://user-images.githubusercontent.com/28949182/77515730-6ecc2100-6ebc-11ea-9bb5-ae40103b51dd.png)  영화가 좋았다 최고였다 라는 표현을 쓰는경우 마스터 피스 라는 단어와 자주 쓰였다고 볼수있다.

# %% [markdown]
# 2. 영화를 칭찬하면서 아카데미 상 에 대해 언급하는데, 이때 기생충이라는 영화와 자주 비교하는 특성을 보인다. 가까운 곳에 마스터 피스, 최고 라는 단어도 찾아 볼수 있는것을 보면 이 단어들은 모두 비슷한 의미에서 사용되었다는것을 알수있다.
# ![image](https://user-images.githubusercontent.com/28949182/77516191-45f85b80-6ebd-11ea-9a13-9c31032210b7.png)

# %% [markdown]
# 3. 요즘 코로나로 인해 영화 개봉이 많은 영향을 받고 있는데 그 역시 짐작할수 있게 군집해서 나온것을 볼수 있다. ![image](https://user-images.githubusercontent.com/28949182/77517656-dd5eae00-6ebf-11ea-9ae3-01fa20504e56.png)

# %%
tsne_plot(CBOW)
# Out:
# C:\Users\MiSung\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if sys.path[0] == '':
# C:\Users\MiSung\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\MiSung\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 1. 영화 리뷰의 특성에서 볼때 "이 글은 스포일러를 포함하고 있다" 라는 문구를 자주 찾아볼수 있는데 실제로 이런 군집을 찾을수 있었다. ![image.png](attachment:image.png)
#
# > 군집을 이룬다는 의미는, 자주 연결되는 문구들이 군집을 이루는것이 아닌가 싶다.

# %% [markdown]
# skim grim에서 원하는 인사이트를 좀더 많이 찾아낼수 있었던거같다.
